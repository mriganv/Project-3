# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../Resources/cpj_govjobs_cleaned.csv')

# %%
df
# Out:
#                                                Job Title  \
# 0                                           Data Analyst
# 1      IT Specialist (DATAMGT) (Data and Reporting An...
# 2                         Program Analyst (Data Science)
# 3                Health System Specialist (Data Analyst)
# 4              Interdisciplinary (Data Research Analyst)
# ...                                                  ...
# 10999  Research Economist       Research Mathematicia...
# 11000  Physical Scientist/Biologist/Mathematical Stat...
# 11001  Physical Scientist/Biologist/Mathematical Stat...
# 11002  Health Statistician - PD21E022 - Center for Qu...
# 11003  Mathematical Statistician (Education), GS-1529...
#
#                                        Company Name   Salary  Job Category  \
# 0      Other Agencies and Independent Organizations  87198.0  Data Analyst
# 1                        Department of the Treasury  92143.0  Data Analyst
# 2                    Department of Veterans Affairs  66829.0  Data Analyst
# 3                    Department of Veterans Affairs  59498.0  Data Analyst
# 4      Other Agencies and Independent Organizations  10369.0  Data Analyst
# ...                                             ...      ...           ...
# 10999                    Department of the Treasury  15818.0  Statistician
# 11000                    Department of the Interior  53433.0  Statistician
# 11001                    Department of the Interior  77488.0  Statistician
# 11002       Department of Health And Human Services  10369.0  Statistician
# 11003                       Department of Education  14412.0  Statistician
#
#                        city                 State
# 0                Washington  District of Columbia
# 1      No location provided                   NaN
# 2      No location provided                   NaN
# 3              West Roxbury         Massachusetts
# 4                Alexandria              Virginia
# ...                     ...                   ...
# 10999            Washington  District of Columbia
# 11000  No location provided                   NaN
# 11001  No location provided                   NaN
# 11002             Rockville              Maryland
# 11003            Washington  District of Columbia
#
# [11004 rows x 6 columns]

# %%
df['Data Analyst'] = (df["Job Title"].str.lower()
                            .str.contains("data analyst", regex=False, na=False)
                            .astype(int))
Data_Analyst_df = df.loc[df['Data Analyst'] == 1]
Data_Analyst_df["Category"] = "Data Analyst"
del Data_Analyst_df["Data Analyst"]
Data_Analyst_df
# Out:
# <ipython-input-5-84dd14c6f739>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data_Analyst_df["Category"] = "Data Analyst"
#                                                Job Title  \
# 0                                           Data Analyst
# 3                Health System Specialist (Data Analyst)
# 11     Supervisory Performance Improvement / Data Ana...
# 12     Supervisory Performance Improvement / Data Ana...
# 837                                         Data Analyst
# 868              Health System Specialist (Data Analyst)
# 882    Supervisory Performance Improvement / Data Ana...
# 883    Supervisory Performance Improvement / Data Ana...
# 1616                                        Data Analyst
# 1680             Health System Specialist (Data Analyst)
# 1731   Supervisory Performance Improvement / Data Ana...
# 1732   Supervisory Performance Improvement / Data Ana...
# 1845                                        Data Analyst
# 1900             Health System Specialist (Data Analyst)
# 1921   Supervisory Performance Improvement / Data Ana...
# 1922   Supervisory Performance Improvement / Data Ana...
# 1955                                        Data Analyst
# 1992             Health System Specialist (Data Analyst)
# 2006   Supervisory Performance Improvement / Data Ana...
# 2007   Supervisory Performance Improvement / Data Ana...
# 3589                                        Data Analyst
# 4240             Health System Specialist (Data Analyst)
# 4304   Supervisory Performance Improvement / Data Ana...
# 4305   Supervisory Performance Improvement / Data Ana...
# 4471                                        Data Analyst
# 5127             Health System Specialist (Data Analyst)
# 5192   Supervisory Performance Improvement / Data Ana...
# 5193   Supervisory Performance Improvement / Data Ana...
# 5465                                        Data Analyst
# 1616   Data Analyst
# 1680   Data Analyst
# 1731   Data Analyst
# 1732   Data Analyst
# 1845   Data Analyst
# 1900   Data Analyst
# 1921   Data Analyst
# 1922   Data Analyst
# 1955   Data Analyst
# 1992   Data Analyst
# 2006   Data Analyst
# 2007   Data Analyst
# 3589   Data Analyst
# 4240   Data Analyst
# 4304   Data Analyst
# 4305   Data Analyst
# 4471   Data Analyst
# 5127   Data Analyst
# 5192   Data Analyst
# 5193   Data Analyst
# 5465   Data Analyst
# 6227   Data Analyst
# 6294   Data Analyst
# 6295   Data Analyst
# 6377   Data Analyst
# 7029   Data Analyst
# 7094   Data Analyst
# 7095   Data Analyst
# 7169   Data Analyst
# 7208   Data Analyst
# 7222   Data Analyst
# 7223   Data Analyst
# 8463   Data Analyst
# 8494   Data Analyst
# 8508   Data Analyst
# 8509   Data Analyst
# 8528   Data Analyst
# 9180   Data Analyst
# 9245   Data Analyst
# 9246   Data Analyst
# 9888   Data Analyst
# 10761  Data Analyst
# 10879  Data Analyst
# 10880  Data Analyst

# %%
df['Computer Scientist'] = df["Job Title"].str.contains("Computer Scientist", case=False, na=False).astype(int)
Computer_Scientist_df = df.loc[df['Computer Scientist'] == 1]
Computer_Scientist_df["Category"] = "Computer Scientist"
del Computer_Scientist_df['Data Analyst']
del Computer_Scientist_df["Computer Scientist"]
# Out:
# <ipython-input-6-282d3e244201>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Computer_Scientist_df["Category"] = "Computer Scientist"

# %%
Computer_Scientist_df
# Out:
#                                                Job Title  \
# 835    INTERDISCIPLINARY COMPUTER SCIENTIST, GENERAL ...
# 1070   Computer Engineer, Computer Scientist, Electri...
# 1287                         COMPUTER SCIENTIST/ENGINEER
# 1364   INTERDISCIPLINARY COMPUTER SCIENTIST/COMPUTER ...
# 1532   Interdisciplinary Computer Engineer / Computer...
# 1603   INTERDISCIPLINARY COMPUTER SCIENTIST, GENERAL ...
# 1655                                  Computer Scientist
# 1658                                  COMPUTER SCIENTIST
# 1659                                  Computer Scientist
# 1661                                  Computer Scientist
# 1663                                  Computer Scientist
# 1664                                  COMPUTER SCIENTIST
# 1669                                  COMPUTER SCIENTIST
# 1671                                  COMPUTER SCIENTIST
# 1698                         COMPUTER SCIENTIST/ENGINEER
# 1781     Student Trainee (Computer Scientist) (PATHWAYS)
# 1790   Computer Scientist, GS-1550-07/09/11/12, Censu...
# 1791   Computer Scientist, GS-1550-07/09/11/12, Censu...
# 1801   Interdisciplinary Computer Engineer / Computer...
# 1805   Public Notice for Computer Scientist Cybersecu...
# 1806   Public Notice for Computer Scientist Cybersecu...
# 1817   Computer Scientist, AST, Computer Research and...
# 1825   INTERDISCIPLINARY COMPUTER SCIENTIST/COMPUTER ...
# 1828   Computer Engineer, Computer Scientist, Electri...
# 1831   INTERDISCIPLINARY COMPUTER SCIENTIST, GENERAL ...
# 2194   Computer Engineer, Computer Scientist, Electri...
# 2413                         COMPUTER SCIENTIST/ENGINEER
# 2490   INTERDISCIPLINARY COMPUTER SCIENTIST/COMPUTER ...
# 2658   Interdisciplinary Computer Engineer / Computer...
# 2729   INTERDISCIPLINARY COMPUTER SCIENTIST, GENERAL ...
# 2926   Computer Engineer, Computer Scientist, Electri...
# 3142                         COMPUTER SCIENTIST/ENGINEER
# 3219   INTERDISCIPLINARY COMPUTER SCIENTIST/COMPUTER ...
# 3389   Interdisciplinary Computer Engineer / Computer...
# 3460   INTERDISCIPLINARY COMPUTER SCIENTIST, GENERAL ...
#
# 20                          Department of the Army  55355.0
# ...                                            ...      ...
# 9794                        Department of the Navy  11500.0
# 9801  Other Agencies and Independent Organizations  12962.0
# 9811                        Department of the Army  12253.0
# 9815                        Department of Commerce  10369.0
# 9816  Other Agencies and Independent Organizations  11019.0
#
#             Job Category                  city                 State  \
# 1           Data Analyst  No location provided                   NaN
# 17          Data Analyst  No location provided                   NaN
# 18          Data Analyst            Washington  District of Columbia
# 19          Data Analyst            Washington  District of Columbia
# 20          Data Analyst               Phoenix               Arizona
# ...                  ...                   ...                   ...
# 9794  IT Systems Analyst              Quantico              Virginia
# 9801  IT Systems Analyst            Washington  District of Columbia
# 9811  IT Systems Analyst              Pentagon              Virginia
# 9815  IT Systems Analyst              Suitland              Maryland
# 9816  IT Systems Analyst  No location provided                   NaN
#
#            Category
# 1     IT Specialist
# 17    IT Specialist
# 18    IT Specialist
# 19    IT Specialist
# 20    IT Specialist
# ...             ...
# 9794  IT Specialist
# 9801  IT Specialist
# 9811  IT Specialist
# 9815  IT Specialist
# 9816  IT Specialist
#
# [442 rows x 7 columns]

# %%
df['Operations Research Analyst'] = (df["Job Title"].str.lower()
                            .str.contains("operations research analyst", regex=False, na=False)
                            .astype(int))
operations_research_analyst_df = df.loc[df['Operations Research Analyst'] == 1]
operations_research_analyst_df["Category"] = "Operations Research Analyst"
del operations_research_analyst_df['Data Analyst']
del operations_research_analyst_df["Computer Scientist"]
del operations_research_analyst_df["IT Specialist"]
del operations_research_analyst_df["Operations Research Analyst"]
operations_research_analyst_df
# Out:
# <ipython-input-10-6f1edc10dd9a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   operations_research_analyst_df["Category"] = "Operations Research Analyst"
#                                                Job Title  \
# 15     Operations Research Analyst (Senior Financial ...
# 16     Operations Research Analyst (Senior Financial ...
# 497                          Operations Research Analyst
# 499                          Operations Research Analyst
# 500                          Operations Research Analyst
# ...                                                  ...
# 10907  Operations Research Analyst-Joint Requirements...
# 10928  Operations Research Analyst (Senior Financial ...
# 10929  Operations Research Analyst (Senior Financial ...
# 10940  General Engineer/Operations Research Analyst (...
# 10941  General Engineer/Operations Research Analyst (...
#
#                           Company Name   Salary        Job Category  \
# 15          Department of the Treasury  13755.0        Data Analyst
# 16          Department of the Treasury  13755.0        Data Analyst
# 497        Department of the Air Force  43683.0        Data Analyst
# 499             Department of the Army  77488.0        Data Analyst
# 500       Department of Transportation  83458.0        Data Analyst
# ...                                ...      ...                 ...
# 10907  Department of Homeland Security  79468.0  IT Systems Analyst
# 10928       Department of the Treasury  13755.0  IT Systems Analyst
# 10929       Department of the Treasury  13755.0  IT Systems Analyst
# 10940  Department of Homeland Security  81057.0  IT Systems Analyst
# 10941  Department of Homeland Security  81057.0  IT Systems Analyst
#
#                             city                 State  \
# 15          No location provided                   NaN
# 16          No location provided                   NaN
# 497         No location provided                   NaN
# 499    White Sands Missile Range            New Mexico
# 500         No location provided                   NaN
# ...                          ...                   ...
# 10907                 Washington  District of Columbia
# 10928       No location provided                   NaN
# 10929       No location provided                   NaN
# 10940       No location provided                   NaN
# 10941       No location provided                   NaN
#
#                           Category
# 15     Operations Research Analyst
# 16     Operations Research Analyst
# 497    Operations Research Analyst
# 499    Operations Research Analyst
# 500    Operations Research Analyst
# ...                            ...
# 10907  Operations Research Analyst
# 10928  Operations Research Analyst
# 10929  Operations Research Analyst
# 10940  Operations Research Analyst
# 10941  Operations Research Analyst
#
# [249 rows x 7 columns]

# %%
df['Data Engineer'] = (df["Job Title"].str.lower()
                            .str.contains("data engineer", regex=False, na=False)
                            .astype(int))
Data_engineer_df = df.loc[df['Data Engineer'] == 1]
Data_engineer_df["Category"] = "Data Enginner"
del Data_engineer_df['Data Analyst']
del Data_engineer_df["Computer Scientist"]
del Data_engineer_df["IT Specialist"]
del Data_engineer_df["Operations Research Analyst"]
del Data_engineer_df["Data Engineer"]
Data_engineer_df
# Out:
# Empty DataFrame
# Columns: [Job Title, Company Name, Salary, Job Category, city, State, Category]
# Index: []

# %%
df['Business Intelligence Specialist'] = (df["Job Title"].str.lower()
                            .str.contains("business intelligence specialist", regex=False, na=False)
                            .astype(int))


Business_intelligence_specialist_df = df.loc[df['Business Intelligence Specialist'] == 1]

Business_intelligence_specialist_df ["Category"] = "Business Intelligence Specialist"
del Business_intelligence_specialist_df ['Data Analyst']
del Business_intelligence_specialist_df ["Computer Scientist"]
del Business_intelligence_specialist_df ["IT Specialist"]
del Business_intelligence_specialist_df ["Operations Research Analyst"]
del Business_intelligence_specialist_df ["Business Intelligence Specialist"]
del Business_intelligence_specialist_df ["Data Engineer"]
Business_intelligence_specialist_df
# Out:
# Empty DataFrame
# Columns: [Job Title, Company Name, Salary, Job Category, city, State, Category]
# Index: []

# %%
df['Research Analyst'] = (df["Job Title"].str.lower()
                            .str.contains("research analyst", regex=False, na=False)
                            .astype(int))


Research_analyst_df = df.loc[df['Research Analyst'] == 1]

Research_analyst_df["Category"] = "Research_Analyst"
del Research_analyst_df ['Data Analyst']
del Research_analyst_df ["Computer Scientist"]
del Research_analyst_df ["IT Specialist"]
del Research_analyst_df ["Operations Research Analyst"]
del Research_analyst_df ["Business Intelligence Specialist"]
del Research_analyst_df ["Research Analyst"]
del Research_analyst_df ["Data Engineer"]
Research_analyst_df
# Out:
# <ipython-input-13-579dc7799bc6>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Research_analyst_df["Category"] = "Research_Analyst"
#                                                Job Title  \
# 4              Interdisciplinary (Data Research Analyst)
# 15     Operations Research Analyst (Senior Financial ...
# 16     Operations Research Analyst (Senior Financial ...
# 497                          Operations Research Analyst
# 499                          Operations Research Analyst
# ...                                                  ...
# 10907  Operations Research Analyst-Joint Requirements...
# 10928  Operations Research Analyst (Senior Financial ...
# 10929  Operations Research Analyst (Senior Financial ...
# 10940  General Engineer/Operations Research Analyst (...
# 10941  General Engineer/Operations Research Analyst (...
#
#                                        Company Name   Salary  \
# 4      Other Agencies and Independent Organizations  10369.0
# 15                       Department of the Treasury  13755.0
# 16                       Department of the Treasury  13755.0
# 497                     Department of the Air Force  43683.0
# 499                          Department of the Army  77488.0
# ...                                             ...      ...
# 10907               Department of Homeland Security  79468.0
# 10928                    Department of the Treasury  13755.0
# 10929                    Department of the Treasury  13755.0
# 10940               Department of Homeland Security  81057.0
# 10941               Department of Homeland Security  81057.0
#
#              Job Category                       city                 State  \
# 4            Data Analyst                 Alexandria              Virginia
# 15           Data Analyst       No location provided                   NaN
# 16           Data Analyst       No location provided                   NaN
# 497          Data Analyst       No location provided                   NaN
# 499          Data Analyst  White Sands Missile Range            New Mexico
# ...                   ...                        ...                   ...
# 10907  IT Systems Analyst                 Washington  District of Columbia
# 10928  IT Systems Analyst       No location provided                   NaN
# 10929  IT Systems Analyst       No location provided                   NaN
# 10940  IT Systems Analyst       No location provided                   NaN
# 10941  IT Systems Analyst       No location provided                   NaN
#
#                Category
# 4      Research_Analyst
# 15     Research_Analyst
# 16     Research_Analyst
# 497    Research_Analyst
# 499    Research_Analyst
# ...                 ...
# 10907  Research_Analyst
# 10928  Research_Analyst
# 10929  Research_Analyst
# 10940  Research_Analyst
# 10941  Research_Analyst
#
# [290 rows x 7 columns]

# %%
df['Chief Data Officer'] = (df["Job Title"].str.lower()
                            .str.contains("cheif data officer", regex=False, na=False)
                            .astype(int))


chief_Data_officer_df = df.loc[df['Chief Data Officer'] == 1]

chief_Data_officer_df["Category"] = "Chief_Data Officer"
del chief_Data_officer_df ['Data Analyst']
del chief_Data_officer_df ["Computer Scientist"]
del chief_Data_officer_df ["IT Specialist"]
del chief_Data_officer_df ["Operations Research Analyst"]
del chief_Data_officer_df ["Business Intelligence Specialist"]
del chief_Data_officer_df ["Research Analyst"]
del chief_Data_officer_df ["Data Engineer"]
del chief_Data_officer_df["Chief Data Officer"]
chief_Data_officer_df
# Out:
# Empty DataFrame
# Columns: [Job Title, Company Name, Salary, Job Category, city, State, Category]
# Index: []

# %%
df['Enterprise Data Manager'] = (df["Job Title"].str.lower()
                            .str.contains("enterprise data manager", regex=False, na=False)
                            .astype(int))


Enterprise_Data_manager= df.loc[df['Enterprise Data Manager'] == 1]

Enterprise_Data_manager["Category"] = "Enterprise Data Manager"
del Enterprise_Data_manager['Data Analyst']
del Enterprise_Data_manager["Computer Scientist"]
del Enterprise_Data_manager["IT Specialist"]
del Enterprise_Data_manager["Operations Research Analyst"]
del Enterprise_Data_manager["Business Intelligence Specialist"]
del Enterprise_Data_manager["Research Analyst"]
del Enterprise_Data_manager["Data Engineer"]
del Enterprise_Data_manager["Chief Data Officer"]
del Enterprise_Data_manager["Enterprise Data Manager"]                                 
Enterprise_Data_manager
# Out:
# Empty DataFrame
# Columns: [Job Title, Company Name, Salary, Job Category, city, State, Category]
# Index: []

# %%
df['Management and Program Analyst'] = (df["Job Title"].str.lower()
                            .str.contains("management and program analyst", regex=False, na=False)
                            .astype(int))


Management_program_Analyst_df= df.loc[df['Management and Program Analyst'] == 1]

Management_program_Analyst_df["Category"] = "Management program Analyst"
del Management_program_Analyst_df ['Data Analyst']
del Management_program_Analyst_df ["Computer Scientist"]
del Management_program_Analyst_df ["IT Specialist"]
del Management_program_Analyst_df ["Operations Research Analyst"]
del Management_program_Analyst_df ["Business Intelligence Specialist"]
del Management_program_Analyst_df ["Research Analyst"]
del Management_program_Analyst_df ["Data Engineer"]
del Management_program_Analyst_df["Chief Data Officer"]
del Management_program_Analyst_df["Enterprise Data Manager"] 
del Management_program_Analyst_df["Management and Program Analyst"]
Management_program_Analyst_df
# Out:
# <ipython-input-16-56bb16f8f937>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Management_program_Analyst_df["Category"] = "Management program Analyst"
#                                                Job Title  \
# 14     Supervisory Management and Program Analyst (Da...
# 413    Management and Program Analyst (Records Manage...
# 441    Management and Program Analyst (Finance and Bu...
# 587                       Management and Program Analyst
# 589                       Management and Program Analyst
# ...                                                  ...
# 10927  Management and Program Analyst (Organizational...
# 10933  Management and Program Analyst (Business Proce...
# 10949  SUPERVISORY MANAGEMENT AND PROGRAM ANALYST (Ch...
# 10950  Management and Program Analyst (Project Manage...
# 10953  Supervisory Management and Program Analyst (Pr...
#
#                           Company Name   Salary        Job Category  \
# 14               Department of Defense  12807.0        Data Analyst
# 413              Department of Justice  10369.0        Data Analyst
# 441       Department of Transportation  73336.0        Data Analyst
# 587    Department of Homeland Security  79468.0        Data Analyst
# 589    Department of Homeland Security  10369.0        Data Analyst
# ...                                ...      ...                 ...
# 10927               Legislative Branch  12253.0  IT Systems Analyst
# 10933        Department of Agriculture  80275.0  IT Systems Analyst
# 10949  Department of Homeland Security  93907.0  IT Systems Analyst
# 10950       Department of the Treasury  92143.0  IT Systems Analyst
# 10953       Department of the Treasury  10999.0  IT Systems Analyst
#
#                        city                 State                    Category
# 14     No location provided                   NaN  Management program Analyst
# 413              Washington  District of Columbia  Management program Analyst
# 441              Washington  District of Columbia  Management program Analyst
# 587    No location provided                   NaN  Management program Analyst
# 589              Washington  District of Columbia  Management program Analyst
# ...                     ...                   ...                         ...
# 10927            Washington  District of Columbia  Management program Analyst
# 10933               Phoenix               Arizona  Management program Analyst
# 10949  No location provided                   NaN  Management program Analyst
# 10950  No location provided                   NaN  Management program Analyst
# 10953  No location provided                   NaN  Management program Analyst
#
# [632 rows x 7 columns]

# %%
df['Management and Program Analyst'].value_counts()
# Out:
# 0    10372
# 1      632
# Name: Management and Program Analyst, dtype: int64

# %%
df['Public Health Analyst'] = (df["Job Title"].str.lower()
                            .str.contains("public health analyst", regex=False, na=False)
                            .astype(int))


public_health_Analyst_df= df.loc[df['Public Health Analyst'] == 1]

public_health_Analyst_df["Category"] = "Public Health Analyst"
del public_health_Analyst_df ['Data Analyst']
del public_health_Analyst_df ["Computer Scientist"]
del public_health_Analyst_df ["IT Specialist"]
del public_health_Analyst_df ["Operations Research Analyst"]
del public_health_Analyst_df ["Business Intelligence Specialist"]
del public_health_Analyst_df ["Research Analyst"]
del public_health_Analyst_df ["Data Engineer"]
del public_health_Analyst_df["Chief Data Officer"]
del public_health_Analyst_df["Enterprise Data Manager"] 
del public_health_Analyst_df["Management and Program Analyst"]
del public_health_Analyst_df["Public Health Analyst"]
public_health_Analyst_df
# Out:
# <ipython-input-18-0e3ae859ff95>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   public_health_Analyst_df["Category"] = "Public Health Analyst"
#                                                Job Title  \
# 407                                Public Health Analyst
# 409                                Public Health Analyst
# 816    Public Health Analyst PD 15R591 / 15R592 - Mat...
# 817    Public Health Analyst PD 15R591 / 15R592 - Mat...
# 827    Supervisory Public Health Analyst - Director, ...
# ...                                                  ...
# 10957  Supervisory Public Health Analyst - Director, ...
# 10961  Public Health Analyst PD 14R325 / 14R326 - Off...
# 10962  Public Health Analyst PD 14R325 / 14R326 - Off...
# 10963  Public Health Analyst PD 14R327 / 14R329 - Off...
# 10964  Public Health Analyst PD 14R327 / 14R329 - Off...
#
#                                   Company Name   Salary        Job Category  \
# 407    Department of Health And Human Services  97078.0        Data Analyst
# 409    Department of Health And Human Services  97078.0        Data Analyst
# 816    Department of Health And Human Services  72750.0        Data Analyst
# 817    Department of Health And Human Services  72750.0        Data Analyst
# 827    Department of Health And Human Services  14412.0        Data Analyst
# ...                                        ...      ...                 ...
# 10957  Department of Health And Human Services  14412.0  IT Systems Analyst
# 10961  Department of Health And Human Services  46083.0  IT Systems Analyst
# 10962  Department of Health And Human Services  46083.0  IT Systems Analyst
# 10963  Department of Health And Human Services  66829.0  IT Systems Analyst
# 10964  Department of Health And Human Services  66829.0  IT Systems Analyst
#
#                        city     State               Category
# 407                 Atlanta   Georgia  Public Health Analyst
# 409                 Atlanta   Georgia  Public Health Analyst
# 816               Rockville  Maryland  Public Health Analyst
# 817               Rockville  Maryland  Public Health Analyst
# 827               Rockville  Maryland  Public Health Analyst
# ...                     ...       ...                    ...
# 10957             Rockville  Maryland  Public Health Analyst
# 10961  No location provided       NaN  Public Health Analyst
# 10962  No location provided       NaN  Public Health Analyst
# 10963  No location provided       NaN  Public Health Analyst
# 10964  No location provided       NaN  Public Health Analyst
#
# [63 rows x 7 columns]

# %%
df['Procurement Analyst'] = (df["Job Title"].str.lower()
                            .str.contains("procurement analyst", regex=False, na=False)
                            .astype(int))


Procurement_Analyst_df= df.loc[df['Procurement Analyst'] == 1]

Procurement_Analyst_df["Category"] = "Procurement Analyst"
del Procurement_Analyst_df ['Data Analyst']
del Procurement_Analyst_df ["Computer Scientist"]
del Procurement_Analyst_df ["IT Specialist"]
del Procurement_Analyst_df ["Operations Research Analyst"]
del Procurement_Analyst_df ["Business Intelligence Specialist"]
del Procurement_Analyst_df ["Research Analyst"]
del Procurement_Analyst_df ["Data Engineer"]
del Procurement_Analyst_df["Chief Data Officer"]
del Procurement_Analyst_df["Enterprise Data Manager"] 
del Procurement_Analyst_df["Management and Program Analyst"]
del Procurement_Analyst_df["Public Health Analyst"]
del Procurement_Analyst_df["Procurement Analyst"]
Procurement_Analyst_df
# Out:
# <ipython-input-19-4be8625f17cb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Procurement_Analyst_df["Category"] = "Procurement Analyst"
#                                                Job Title  \
# 392                                  Procurement Analyst
# 393                                  Procurement Analyst
# 394                                  Procurement Analyst
# 395                                  PROCUREMENT ANALYST
# 396                                  Procurement Analyst
# ...                                                  ...
# 10786          Procurement Analyst (Public Notice Flyer)
# 10890  Contract Specialist/Procurement Analyst - Dire...
# 10891  Contract Specialist/Procurement Analyst (Direc...
# 10892  Contract Specialist/Procurement Analyst (Direc...
# 10952  Contract Spec/Administrator/Negotiator, Procur...
#
#                           Company Name   Salary        Job Category  \
# 392             Department of the Army  92143.0        Data Analyst
# 393              Department of Defense  10369.0        Data Analyst
# 394    General Services Administration  10102.0        Data Analyst
# 395        Department of the Air Force  92143.0        Data Analyst
# 396        Department of the Air Force  78624.0        Data Analyst
# ...                                ...      ...                 ...
# 10786  Department of Homeland Security  10369.0  IT Systems Analyst
# 10890     Department of Transportation  82721.0  IT Systems Analyst
# 10891     Department of Transportation  64009.0  IT Systems Analyst
# 10892     Department of Transportation  10780.0  IT Systems Analyst
# 10952  General Services Administration  64649.0  IT Systems Analyst
#
#                                           city                 State  \
# 392                                     Mobile               Alabama
# 393    New Cumberland Defense Logistics Center          Pennsylvania
# 394                                   Lakewood              Colorado
# 395                                   Hill AFB                  Utah
# 396                                  Scott AFB              Illinois
# ...                                        ...                   ...
# 10786                               Washington  District of Columbia
# 10890                                Cambridge         Massachusetts
# 10891                     No location provided                   NaN
# 10892                     No location provided                   NaN
# 10952                     No location provided                   NaN
#
#                   Category
# 392    Procurement Analyst
# 393    Procurement Analyst
# 394    Procurement Analyst
# 395    Procurement Analyst
# 396    Procurement Analyst
# ...                    ...
# 10786  Procurement Analyst
# 10890  Procurement Analyst
# 10891  Procurement Analyst
# 10892  Procurement Analyst
# 10952  Procurement Analyst
#
# [126 rows x 7 columns]

# %%
df['Health Insurance Analyst'] = (df["Job Title"].str.lower()
                            .str.contains("health insurance analyst", regex=False, na=False)
                            .astype(int))


health_insurance_Analyst_df= df.loc[df['Health Insurance Analyst'] == 1]

health_insurance_Analyst_df["Category"] = "Health Insurance Analyst"
del health_insurance_Analyst_df ['Data Analyst']
del health_insurance_Analyst_df ["Computer Scientist"]
del health_insurance_Analyst_df ["IT Specialist"]
del health_insurance_Analyst_df ["Operations Research Analyst"]
del health_insurance_Analyst_df ["Business Intelligence Specialist"]
del health_insurance_Analyst_df ["Research Analyst"]
del health_insurance_Analyst_df ["Data Engineer"]
del health_insurance_Analyst_df["Chief Data Officer"]
del health_insurance_Analyst_df["Enterprise Data Manager"] 
del health_insurance_Analyst_df["Management and Program Analyst"]
del health_insurance_Analyst_df["Public Health Analyst"]
del health_insurance_Analyst_df["Procurement Analyst"]
del health_insurance_Analyst_df["Health Insurance Analyst"]
health_insurance_Analyst_df
# Out:
# Empty DataFrame
# Columns: [Job Title, Company Name, Salary, Job Category, city, State, Category]
# Index: []

# %%
df['Social Science Analyst'] = (df["Job Title"].str.lower()
                            .str.contains("social science analyst", regex=False, na=False)
                            .astype(int))


Social_Science_Analyst_df= df.loc[df['Social Science Analyst'] == 1]

Social_Science_Analyst_df["Category"] = "Social Science Analyst"
del Social_Science_Analyst_df ['Data Analyst']
del Social_Science_Analyst_df ["Computer Scientist"]
del Social_Science_Analyst_df ["IT Specialist"]
del Social_Science_Analyst_df ["Operations Research Analyst"]
del Social_Science_Analyst_df ["Business Intelligence Specialist"]
del Social_Science_Analyst_df ["Research Analyst"]
del Social_Science_Analyst_df ["Data Engineer"]
del Social_Science_Analyst_df["Chief Data Officer"]
del Social_Science_Analyst_df["Enterprise Data Manager"] 
del Social_Science_Analyst_df["Management and Program Analyst"]
del Social_Science_Analyst_df["Public Health Analyst"]
del Social_Science_Analyst_df["Procurement Analyst"]
del Social_Science_Analyst_df["Health Insurance Analyst"]
del Social_Science_Analyst_df["Social Science Analyst"]                                    
Social_Science_Analyst_df
# Out:
# Empty DataFrame
# Columns: [Job Title, Company Name, Salary, Job Category, city, State, Category]
# Index: []

# %%
df['Policy Advisor'] = (df["Job Title"].str.lower()
                            .str.contains("policy advisor", regex=False, na=False)
                            .astype(int))


Policy_advisor_df= df.loc[df['Policy Advisor'] == 1]

Policy_advisor_df["Category"] = "Policy Advisor"
del Policy_advisor_df ['Data Analyst']
del Policy_advisor_df ["Computer Scientist"]
del Policy_advisor_df ["IT Specialist"]
del Policy_advisor_df ["Operations Research Analyst"]
del Policy_advisor_df ["Business Intelligence Specialist"]
del Policy_advisor_df ["Research Analyst"]
del Policy_advisor_df ["Data Engineer"]
del Policy_advisor_df["Chief Data Officer"]
del Policy_advisor_df["Enterprise Data Manager"] 
del Policy_advisor_df["Management and Program Analyst"]
del Policy_advisor_df["Public Health Analyst"]
del Policy_advisor_df["Procurement Analyst"]
del Policy_advisor_df["Health Insurance Analyst"]
del Policy_advisor_df["Social Science Analyst"]
del Policy_advisor_df["Policy Advisor"]
Policy_advisor_df
# Out:
# Empty DataFrame
# Columns: [Job Title, Company Name, Salary, Job Category, city, State, Category]
# Index: []

# %%
df['Mathematical Analyst'] = (df["Job Title"].str.lower()
                            .str.contains("mathematical analyst", regex=False, na=False)
                            .astype(int))


Mathematical_Analyst_df= df.loc[df['Mathematical Analyst'] == 1]

Mathematical_Analyst_df["Category"] = "Mathematical Analyst"
del Mathematical_Analyst_df ['Data Analyst']
del Mathematical_Analyst_df ["Computer Scientist"]
del Mathematical_Analyst_df ["IT Specialist"]
del Mathematical_Analyst_df ["Operations Research Analyst"]
del Mathematical_Analyst_df ["Business Intelligence Specialist"]
del Mathematical_Analyst_df ["Research Analyst"]
del Mathematical_Analyst_df ["Data Engineer"]
del Mathematical_Analyst_df["Chief Data Officer"]
del Mathematical_Analyst_df["Enterprise Data Manager"] 
del Mathematical_Analyst_df["Management and Program Analyst"]
del Mathematical_Analyst_df["Public Health Analyst"]
del Mathematical_Analyst_df["Procurement Analyst"]
del Mathematical_Analyst_df["Health Insurance Analyst"]
del Mathematical_Analyst_df["Social Science Analyst"]
del Mathematical_Analyst_df["Policy Advisor"]
del Mathematical_Analyst_df["Mathematical Analyst"]
Mathematical_Analyst_df
# Out:
# Empty DataFrame
# Columns: [Job Title, Company Name, Salary, Job Category, city, State, Category]
# Index: []

# %%
df['Economic Research Analyst'] = (df["Job Title"].str.lower()
                            .str.contains("economic eesearch enalyst", regex=False, na=False)
                            .astype(int))

Economic_Research_Analyst_df= df.loc[df['Economic Research Analyst'] == 1]

Economic_Research_Analyst_df["Category"] = "Economic Research Analyst"
del Economic_Research_Analyst_df ['Data Analyst']
del Economic_Research_Analyst_df ["Computer Scientist"]
del Economic_Research_Analyst_df ["IT Specialist"]
del Economic_Research_Analyst_df ["Operations Research Analyst"]
del Economic_Research_Analyst_df ["Business Intelligence Specialist"]
del Economic_Research_Analyst_df ["Research Analyst"]
del Economic_Research_Analyst_df ["Data Engineer"]
del Economic_Research_Analyst_df["Chief Data Officer"]
del Economic_Research_Analyst_df["Enterprise Data Manager"] 
del Economic_Research_Analyst_df["Management and Program Analyst"]
del Economic_Research_Analyst_df["Public Health Analyst"]
del Economic_Research_Analyst_df["Procurement Analyst"]
del Economic_Research_Analyst_df["Health Insurance Analyst"]
del Economic_Research_Analyst_df["Social Science Analyst"]
del Economic_Research_Analyst_df["Policy Advisor"]
del Economic_Research_Analyst_df["Mathematical Analyst"]
del Economic_Research_Analyst_df["Economic Research Analyst"]
Economic_Research_Analyst_df
# Out:
# Empty DataFrame
# Columns: [Job Title, Company Name, Salary, Job Category, city, State, Category]
# Index: []

# %%
all_dfs = [Data_Analyst_df, Computer_Scientist_df, it_specialist_df, operations_research_analyst_df,
          Research_analyst_df, Management_program_Analyst_df, public_health_Analyst_df, Procurement_Analyst_df]
          

usa_gov_jobs_df = pd.concat(all_dfs).reset_index(drop=True)

# %%
usa_gov_jobs_df
# Out:
#                                               Job Title  \
# 0                                          Data Analyst
# 1               Health System Specialist (Data Analyst)
# 2     Supervisory Performance Improvement / Data Ana...
# 3     Supervisory Performance Improvement / Data Ana...
# 4                                          Data Analyst
# ...                                                 ...
# 1890          Procurement Analyst (Public Notice Flyer)
# 1891  Contract Specialist/Procurement Analyst - Dire...
# 1892  Contract Specialist/Procurement Analyst (Direc...
# 1893  Contract Specialist/Procurement Analyst (Direc...
# 1894  Contract Spec/Administrator/Negotiator, Procur...
#
#                                       Company Name   Salary  \
# 0     Other Agencies and Independent Organizations  87198.0
# 1                   Department of Veterans Affairs  59498.0
# 2          Department of Health And Human Services  92723.0
# 3          Department of Health And Human Services  92723.0
# 4     Other Agencies and Independent Organizations  87198.0
# ...                                            ...      ...
# 1890               Department of Homeland Security  10369.0
# 1891                  Department of Transportation  82721.0
# 1892                  Department of Transportation  64009.0
# 1893                  Department of Transportation  10780.0
# 1894               General Services Administration  64649.0
#
#             Job Category                  city                 State  \
# 0           Data Analyst            Washington  District of Columbia
# 1           Data Analyst          West Roxbury         Massachusetts
# 2           Data Analyst                Gallup            New Mexico
# 3           Data Analyst                Gallup            New Mexico
# 4          Data Engineer            Washington  District of Columbia
# ...                  ...                   ...                   ...
# 1890  IT Systems Analyst            Washington  District of Columbia
# 1891  IT Systems Analyst             Cambridge         Massachusetts
# 1892  IT Systems Analyst  No location provided                   NaN
# 1893  IT Systems Analyst  No location provided                   NaN
# 1894  IT Systems Analyst  No location provided                   NaN
#
#                  Category
# 0            Data Analyst
# 1            Data Analyst
# 2            Data Analyst
# 3            Data Analyst
# 4            Data Analyst
# ...                   ...
# 1890  Procurement Analyst
# 1891  Procurement Analyst
# 1892  Procurement Analyst
# 1893  Procurement Analyst
# 1894  Procurement Analyst
#
# [1895 rows x 7 columns]

# %%
usa_gov_jobs_df["Category"].unique()
# Out:
# array(['Data Analyst', 'Computer Scientist', 'IT Specialist',
#        'Operations Research Analyst', 'Research_Analyst',
#        'Management program Analyst', 'Public Health Analyst',
#        'Procurement Analyst'], dtype=object)

# %%
usa_gov_jobs_df.dropna(axis=1, how='all')
# Out:
#                                               Job Title  \
# 0                                          Data Analyst
# 1               Health System Specialist (Data Analyst)
# 2     Supervisory Performance Improvement / Data Ana...
# 3     Supervisory Performance Improvement / Data Ana...
# 4                                          Data Analyst
# ...                                                 ...
# 1890          Procurement Analyst (Public Notice Flyer)
# 1891  Contract Specialist/Procurement Analyst - Dire...
# 1892  Contract Specialist/Procurement Analyst (Direc...
# 1893  Contract Specialist/Procurement Analyst (Direc...
# 1894  Contract Spec/Administrator/Negotiator, Procur...
#
#                                       Company Name   Salary  \
# 0     Other Agencies and Independent Organizations  87198.0
# 1                   Department of Veterans Affairs  59498.0
# 2          Department of Health And Human Services  92723.0
# 3          Department of Health And Human Services  92723.0
# 4     Other Agencies and Independent Organizations  87198.0
# ...                                            ...      ...
# 1890               Department of Homeland Security  10369.0
# 1891                  Department of Transportation  82721.0
# 1892                  Department of Transportation  64009.0
# 1893                  Department of Transportation  10780.0
# 1894               General Services Administration  64649.0
#
#             Job Category                  city                 State  \
# 0           Data Analyst            Washington  District of Columbia
# 1           Data Analyst          West Roxbury         Massachusetts
# 2           Data Analyst                Gallup            New Mexico
# 3           Data Analyst                Gallup            New Mexico
# 4          Data Engineer            Washington  District of Columbia
# ...                  ...                   ...                   ...
# 1890  IT Systems Analyst            Washington  District of Columbia
# 1891  IT Systems Analyst             Cambridge         Massachusetts
# 1892  IT Systems Analyst  No location provided                   NaN
# 1893  IT Systems Analyst  No location provided                   NaN
# 1894  IT Systems Analyst  No location provided                   NaN
#
#                  Category
# 0            Data Analyst
# 1            Data Analyst
# 2            Data Analyst
# 3            Data Analyst
# 4            Data Analyst
# ...                   ...
# 1890  Procurement Analyst
# 1891  Procurement Analyst
# 1892  Procurement Analyst
# 1893  Procurement Analyst
# 1894  Procurement Analyst
#
# [1895 rows x 7 columns]

# %%
del usa_gov_jobs_df["Job Category"]
usa_gov_jobs_df['Salary']=usa_gov_jobs_df['Salary'].apply(lambda x:round(x,2))

# %%
usa_gov_jobs_df["Category"].unique().tolist()
# Out:
# ['Data Analyst',
#  'Computer Scientist',
#  'IT Specialist',
#  'Operations Research Analyst',
#  'Research_Analyst',
#  'Management program Analyst',
#  'Public Health Analyst',
#  'Procurement Analyst']

# %%
usa_gov_jobs_df["Category"].value_counts()
# Out:
# Management program Analyst     632
# IT Specialist                  442
# Research_Analyst               290
# Operations Research Analyst    249
# Procurement Analyst            126
# Public Health Analyst           63
# Data Analyst                    52
# Computer Scientist              41
# Name: Category, dtype: int64

# %%
usa_gov_jobs_df.rename(columns={'Job Title':'Position Title'}, inplace=True)
usa_gov_jobs_df.rename(columns={'Category':'Job Title'}, inplace=True)
usa_gov_jobs_df.rename(columns={'State':'State Name'}, inplace=True)
usa_gov_jobs_df
# Out:
#                                          Position Title  \
# 0                                          Data Analyst
# 1               Health System Specialist (Data Analyst)
# 2     Supervisory Performance Improvement / Data Ana...
# 3     Supervisory Performance Improvement / Data Ana...
# 4                                          Data Analyst
# ...                                                 ...
# 1890          Procurement Analyst (Public Notice Flyer)
# 1891  Contract Specialist/Procurement Analyst - Dire...
# 1892  Contract Specialist/Procurement Analyst (Direc...
# 1893  Contract Specialist/Procurement Analyst (Direc...
# 1894  Contract Spec/Administrator/Negotiator, Procur...
#
#                                       Company Name   Salary  \
# 0     Other Agencies and Independent Organizations  87198.0
# 1                   Department of Veterans Affairs  59498.0
# 2          Department of Health And Human Services  92723.0
# 3          Department of Health And Human Services  92723.0
# 4     Other Agencies and Independent Organizations  87198.0
# ...                                            ...      ...
# 1890               Department of Homeland Security  10369.0
# 1891                  Department of Transportation  82721.0
# 1892                  Department of Transportation  64009.0
# 1893                  Department of Transportation  10780.0
# 1894               General Services Administration  64649.0
#
#                       city            State Name            Job Title
# 0               Washington  District of Columbia         Data Analyst
# 1             West Roxbury         Massachusetts         Data Analyst
# 2                   Gallup            New Mexico         Data Analyst
# 3                   Gallup            New Mexico         Data Analyst
# 4               Washington  District of Columbia         Data Analyst
# ...                    ...                   ...                  ...
# 1890            Washington  District of Columbia  Procurement Analyst
# 1891             Cambridge         Massachusetts  Procurement Analyst
# 1892  No location provided                   NaN  Procurement Analyst
# 1893  No location provided                   NaN  Procurement Analyst
# 1894  No location provided                   NaN  Procurement Analyst
#
# [1895 rows x 6 columns]

# %%
usa_gov_jobs_df["Salary"]= usa_gov_jobs_df["Salary"].astype('int')

# %%
usa_gov_jobs_df.to_csv("../Resources/cpj_usajobs_categorized.csv", index=False)
