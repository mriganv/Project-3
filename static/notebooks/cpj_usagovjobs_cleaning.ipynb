# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("mw_govjob_listings_scraped.csv")

# %%
df
# Out:
#                                                Job Title  \
# 0                                           Data Analyst
# 1      IT Specialist (DATAMGT) (Data and Reporting An...
# 2                         Program Analyst (Data Science)
# 3                Health System Specialist (Data Analyst)
# 4              Interdisciplinary (Data Research Analyst)
# ...                                                  ...
# 11282  Research Economist       Research Mathematicia...
# 11283  Physical Scientist/Biologist/Mathematical Stat...
# 11284  Physical Scientist/Biologist/Mathematical Stat...
# 11285  Health Statistician - PD21E022 - Center for Qu...
# 11286  Mathematical Statistician (Education), GS-1529...
#
#                                        Company Name  \
# 0      Other Agencies and Independent Organizations
# 1                        Department of the Treasury
# 2                    Department of Veterans Affairs
# 3                    Department of Veterans Affairs
# ...

# %%
df = df.drop('Description', axis=1)
df = df.drop('Link', axis=1)

# %%
df.drop(df.loc[df['Salary']==''].index, inplace=True)

# %%
df['Salary'] = df['Salary'].str.replace('Starting at','')

# %%
df['Salary'] =df['Salary'] .str[:8]

# %%
df['Salary'] = df['Salary'].str.replace('$','')
df['Salary'] = df['Salary'].str.replace('NF','')
df['Salary'] = df['Salary'].str.replace('(','')
df['Salary'] = df['Salary'].str.replace(',','')
df['Salary'] = df['Salary'].str.replace('0 GS','')
df['Salary'] = df['Salary'].str.replace('0 HS','')

# %%
df.dtypes
# Out:
# Job Title           object
# Company Name        object
# Company Location    object
# Salary              object
# Job Category        object
# dtype: object

# %%
df['Salary'] = df['Salary'].replace(np.nan, 0)

# %%
df['Salary'] = df['Salary'].str.strip()

# %%
df['Salary'] = df['Salary'].fillna('')

# %%
df['Salary'] = df['Salary'].str.strip()

# %%
# df["Salary"] = df['Salary'].str.replace(' ', '').astype(float)

# %%
df['Salary'] = pd.to_numeric(df['Salary'], downcast='float')

# %%
df['Salary'] = df['Salary'].apply(lambda x: x*2000 if x<100 else x)

# %%
df
# Out:
#                                                Job Title  \
# 0                                           Data Analyst
# 1      IT Specialist (DATAMGT) (Data and Reporting An...
# 2                         Program Analyst (Data Science)
# 3                Health System Specialist (Data Analyst)
# 4              Interdisciplinary (Data Research Analyst)
# ...                                                  ...
# 11282  Research Economist       Research Mathematicia...
# 11283  Physical Scientist/Biologist/Mathematical Stat...
# 11284  Physical Scientist/Biologist/Mathematical Stat...
# 11285  Health Statistician - PD21E022 - Center for Qu...
# 11286  Mathematical Statistician (Education), GS-1529...
#
#                                        Company Name  \
# 0      Other Agencies and Independent Organizations
# 1                        Department of the Treasury
# 2                    Department of Veterans Affairs
# 3                    Department of Veterans Affairs
# ...

# %%
df['Company Location'].unique().tolist()
# Out:
# ['Washington, District of Columbia',
#  'No location provided',
#  'West Roxbury, Massachusetts',
#  'Alexandria, Virginia',
#  'Indianapolis, Indiana',
#  'Woodlawn, Maryland',
#  'Gallup, New Mexico',
#  'Quantico, Virginia',
#  'Phoenix, Arizona',
#  'Andrews AFB, Maryland',
#  'Whitehall, Ohio',
#  'Fort Meade, Maryland',
#  'Montgomery, Alabama',
#  'Washington DC, District of Columbia',
#  'Arlington, Virginia',
#  'Bethesda, Maryland',
#  'District of Columbia, District of Columbia',
#  'Key West, Florida',
#  'Baton Rouge, Louisiana',
#  'Wright-Patterson AFB, Ohio',
#  'Greenbelt, Maryland',
#  'Air Force Academy, Colorado',
#  'Fort Sam Houston, Texas',
#  'Fort Huachuca, Arizona',
#  'Naval Air Station Jacksonville, Florida',
#  'Norfolk, Virginia',
#  'Germantown, Maryland',
#  'Riyadh, Saudi Arabia',
#  'Walla Walla, Washington',
#  'Hanscom AFB, Massachusetts',
#  'Otis ANG Base, Massachusetts',
#  'Silver Spring, Maryland',
#  'College Park, Maryland',
# ...

# %%
# df['Company Location'] = df['Company Location'].str.strip()

# %%
df_company_location = df.join(df['Company Location'].str.split(',', 1, expand=True).rename(columns={0:'city', 1:'State'}))

# %%
df_company_location
# Out:
#                                                Job Title  \
# 0                                           Data Analyst
# 1      IT Specialist (DATAMGT) (Data and Reporting An...
# 2                         Program Analyst (Data Science)
# 3                Health System Specialist (Data Analyst)
# 4              Interdisciplinary (Data Research Analyst)
# ...                                                  ...
# 11282  Research Economist       Research Mathematicia...
# 11283  Physical Scientist/Biologist/Mathematical Stat...
# 11284  Physical Scientist/Biologist/Mathematical Stat...
# 11285  Health Statistician - PD21E022 - Center for Qu...
# 11286  Mathematical Statistician (Education), GS-1529...
#
#                                        Company Name  \
# 0      Other Agencies and Independent Organizations
# 1                        Department of the Treasury
# 2                    Department of Veterans Affairs
# 3                    Department of Veterans Affairs
# ...

# %%
df_company_location= df_company_location.drop(df_company_location.loc[df_company_location['State']==' Saudi Arabia'].index, inplace=True)

# %%
df_company_location.drop(df_company_location.loc[df_company_location['State']=='Philippines'].index, inplace=True)

# %%
df_company_location.drop(df_company_location.loc[df_company_location['State']=='Qatar'].index, inplace=False)

# %%
df_company_location.drop(df_company_location.loc[df_company_location['State']=='Greece'].index, inplace=True)

# %%
df_company_location

# %%
df_company_location=df_company_location.drop(df_company_location.loc[df_company_location['State']==' Qatar'].index, inplace=False)

# %%
df_company_location.drop(df_company_location.loc[df_company_location['State']==' Bahrain'].index, inplace=True)

# %%
df_company_location['State'].unique().tolist()

# %%
df_company_location=df_company_location.drop(df_company_location.loc[df_company_location['State']==' Greece'].index, inplace=True)
df_company_location.drop(df_company_location.loc[df_company_location['State']==' Bahrain'].index, inplace=True)
df_company_location.drop(df_company_location.loc[df_company_location['State']==' Camp Zama, Japan'].index, inplace=True)
df_company_location.drop(df_company_location.loc[df_company_location['State']==' Netherlands'].index, inplace=True)
df_company_location.drop(df_company_location.loc[df_company_location['State']==' Philippines'].index, inplace=True)
df_company_location.drop(df_company_location.loc[df_company_location['State']==' Jordan'].index, inplace=True)
df_company_location.drop(df_company_location.loc[df_company_location['State']==' Bosnia and Herzegovina'].index, inplace=True)
df_company_location.drop(df_company_location.loc[df_company_location['State']==' Nigeria'].index, inplace=True)
df_company_location.drop(df_company_location.loc[df_company_location['State']==' Italy'].index, inplace=True)
df_company_location.drop(df_company_location.loc[df_company_location['State']==' Belgium'].index, inplace=True)
df_company_location.drop(df_company_location.loc[df_company_location['State']==' Japan'].index, inplace=True)
df_company_location.drop(df_company_location.loc[df_company_location['State']==' Kuwait'].index, inplace=True)
df_company_location.drop(df_company_location.loc[df_company_location['State']==' Vietnam'].index, inplace=True)
df_company_location.drop(df_company_location.loc[df_company_location['State']==' Germany'].index, inplace=True)
df_company_location.drop(df_company_location.loc[df_company_location['State']==' Austria'].index, inplace=True)
df_company_location.drop(df_company_location.loc[df_company_location['State']==' Cuba'].index, inplace=True)
df_company_location.drop(df_company_location.loc[df_company_location['State']==' Spain'].index, inplace=True)
df_company_location.drop(df_company_location.loc[df_company_location['State']==''].index, inplace=True)
df_company_location['State'] = df_company_location['State'].str.replace('Oahu, ','')
df_company_location['State'] = df_company_location['State'].str.replace('Mechanicsburg, ','')
df_company_location['State'] = df_company_location['State'].str.replace('Philadelphia, ','')
df_company_location['State'] = df_company_location['State'].str.replace('Atlantic, ','')
df_company_location['State'] = df_company_location['State'].str.replace('Charleston, ','')
df_company_location['State'] = df_company_location['State'].str.replace('San Diego, ','')
df_company_location['State'] = df_company_location['State'].str.replace('Mechanicsburg Detach., ','')
df_company_location['State'] = df_company_location['State'].str.replace('Mechanicsburg Detach., ','')
df_company_location['State'] = df_company_location['State'].str.replace('Portsmouth, ','')
df_company_location['State'] = df_company_location['State'].str.replace('Portsmouth, ','')
df_company_location['State'] = df_company_location['State'].str.replace('Norfolk, Virginia','')
df_company_location['State'] = df_company_location['State'].str.replace('Arlington, ','')
df_company_location['State'] = df_company_location['State'].str.replace("''",'')
df_company_location["State"] =df_company_location["State"].str.strip()

# %%
df_company_location['State'].unique().tolist()

# %%
df_company_location['State'].nunique()

# %%
df_company_location

# %%
df_company_location = df_company_location.drop('Company Location', axis=1)

# %%
df_company_location.to_csv("cpj_govjobs_cleaned4.csv", index=False)
