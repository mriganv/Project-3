# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../Resources/cpj_usajobcategorized_with_description.csv")

# %%
df
# Out:
#                                          Position Title  \
# 0                                          Data Analyst
# 1               Health System Specialist (Data Analyst)
# 2     Supervisory Performance Improvement / Data Ana...
# 3     Supervisory Performance Improvement / Data Ana...
# 4                                          Data Analyst
# ...                                                 ...
# 1890          Procurement Analyst (Public Notice Flyer)
# 1891  Contract Specialist/Procurement Analyst - Dire...
# 1892  Contract Specialist/Procurement Analyst (Direc...
# 1893  Contract Specialist/Procurement Analyst (Direc...
# 1894  Contract Spec/Administrator/Negotiator, Procur...
#
#                                       Company Name  \
# 0     Other Agencies and Independent Organizations
# 1                   Department of Veterans Affairs
# 2          Department of Health And Human Services
# 3          Department of Health And Human Services
# ...

# %%
df["Data Modeling"] = (df["Description"].str.lower()
                            .str.contains("data modeling", regex=False, na=False)
                            .astype(int))
Data_Modeling_df = df.loc[df["Data Modeling"]== 1]
Data_Modeling_df["Skills"] = "Data Modeling"
del Data_Modeling_df["Data Modeling"]
Data_Modeling_df
# Out:
# <ipython-input-8-7da672a3aeaf>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data_Modeling_df["Skills"] = "Data Modeling"
#                     Position Title                Company Name  \
# 95         IT Specialist (DATAMGT)  Department of the Treasury
# 96         IT Specialist (DATAMGT)  Department of the Treasury
# 100  IT SPECIALIST (DATAMGT) (T32)      Department of the Army
# 116        IT Specialist (DATAMGT)  Department of the Treasury
# 117        IT Specialist (DATAMGT)  Department of the Treasury
# 121  IT SPECIALIST (DATAMGT) (T32)      Department of the Army
# 136        IT Specialist (DATAMGT)  Department of the Treasury
# 137        IT Specialist (DATAMGT)  Department of the Treasury
# ...

# %%
df["Data Mining"] = (df["Description"].str.lower()
                            .str.contains("data mining", regex=False, na=False)
                            .astype(int))
Data_Mining_df = df.loc[df["Data Mining"]== 1]
Data_Mining_df["Skills"] = "Data Mining"
del Data_Mining_df["Data Mining"]
del Data_Mining_df["Data Modeling"]
Data_Mining_df
# Out:
# <ipython-input-9-023e8490a9cd>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data_Mining_df["Skills"] = "Data Mining"
#                        Position Title                    Company Name  \
# 102   IT SPECIALIST (NETWORK/DATAMGT)          Department of the Army
# 103   IT Specialist (Data Management)  Department of Veterans Affairs
# 123   IT SPECIALIST (NETWORK/DATAMGT)          Department of the Army
# 124   IT Specialist (Data Management)  Department of Veterans Affairs
# 143   IT SPECIALIST (NETWORK/DATAMGT)          Department of the Army
# 144   IT Specialist (Data Management)  Department of Veterans Affairs
# 163   IT SPECIALIST (NETWORK/DATAMGT)          Department of the Army
# ...

# %%
df["Data Migration"] = (df["Description"].str.lower()
                            .str.contains("data migration", regex=False, na=False)
                            .astype(int))
Data_Migration_df = df.loc[df["Data Migration"]== 1]
Data_Migration_df["Skills"] = "Data Mining"
del Data_Migration_df["Data Mining"]
del Data_Migration_df["Data Modeling"]
del Data_Migration_df["Data Migration"]
Data_Migration_df
# Out:
# Empty DataFrame
# Columns: [Position Title, Company Name, Company Location, Salary, Description, city, State Name, Job Title, Skills]
# Index: []

# %%
df["Data Cleaning"] = (df["Description"].str.lower()
                            .str.contains("data cleaning", regex=False, na=False)
                            .astype(int))
Data_Cleaning_df = df.loc[df["Data Cleaning"]== 1]
Data_Cleaning_df["Skills"] = "Data Cleaning"
del Data_Cleaning_df["Data Mining"]
del Data_Cleaning_df["Data Modeling"]
del Data_Cleaning_df["Data Migration"]
del Data_Cleaning_df["Data Cleaning"]
Data_Cleaning_df
# Out:
# Empty DataFrame
# Columns: [Position Title, Company Name, Company Location, Salary, Description, city, State Name, Job Title, Skills]
# Index: []

# %%
df["Data Integration"] = (df["Description"].str.lower()
                            .str.contains("data integration", regex=False, na=False)
                            .astype(int))
Data_Integration_df = df.loc[df["Data Integration"]== 1]
Data_Integration_df["Skills"] = "Data Integration"
del Data_Integration_df["Data Mining"]
del Data_Integration_df["Data Modeling"]
del Data_Integration_df["Data Migration"]
del Data_Integration_df["Data Cleaning"]
del Data_Integration_df["Data Integration"]
Data_Integration_df
# Out:
# Empty DataFrame
# Columns: [Position Title, Company Name, Company Location, Salary, Description, city, State Name, Job Title, Skills]
# Index: []

# %%
df["Data Collection"] = (df["Description"].str.lower()
                            .str.contains("data collection", regex=False, na=False)
                            .astype(int))
Data_Collection_df = df.loc[df["Data Collection"]== 1]
Data_Collection_df["Skills"] = "Data Collection"
del Data_Collection_df["Data Mining"]
del Data_Collection_df["Data Modeling"]
del Data_Collection_df["Data Migration"]
del Data_Collection_df["Data Cleaning"]
del Data_Collection_df["Data Collection"]
del Data_Collection_df["Data Integration"]
Data_Collection_df
# Out:
# <ipython-input-13-56732a00a6aa>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data_Collection_df["Skills"] = "Data Collection"
#                                          Position Title  \
# 2     Supervisory Performance Improvement / Data Ana...
# 3     Supervisory Performance Improvement / Data Ana...
# 6     Supervisory Performance Improvement / Data Ana...
# 7     Supervisory Performance Improvement / Data Ana...
# 10    Supervisory Performance Improvement / Data Ana...
# ...                                                 ...
# 1458                     Management and Program Analyst
# 1529  Management and Program Analyst (Records Manage...
# 1553                     Management and Program Analyst
# ...

# %%
df["Data Visualization"] = (df["Description"].str.lower()
                            .str.contains("data visualization", regex=False, na=False)
                            .astype(int))
Data_visualization_df = df.loc[df["Data Visualization"]== 1]
Data_visualization_df["Skills"] = "Data Visualization"
del Data_visualization_df["Data Mining"]
del Data_visualization_df["Data Modeling"]
del Data_visualization_df["Data Migration"]
del Data_visualization_df["Data Cleaning"]
del Data_visualization_df["Data Integration"]
del Data_visualization_df["Data Collection"]
del Data_visualization_df["Data Visualization"]
Data_visualization_df
# Out:
# <ipython-input-14-3550e1a91269>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data_visualization_df["Skills"] = "Data Visualization"
#                                          Position Title  \
# 0                                          Data Analyst
# 4                                          Data Analyst
# 8                                          Data Analyst
# 12                                         Data Analyst
# 16                                         Data Analyst
# ...                                                 ...
# 1032  Operations Research Analyst (Senior Financial ...
# 1033  Operations Research Analyst (Senior Financial ...
# 1055                        Operations Research Analyst
# ...

# %%
df["Data Extraction"] = (df["Description"].str.lower()
                            .str.contains("data extraction", regex=False, na=False)
                            .astype(int))
Data_extraction_df = df.loc[df["Data Extraction"]== 1]
Data_extraction_df["Skills"] = "Data Extraction"
del Data_extraction_df["Data Mining"]
del Data_extraction_df["Data Modeling"]
del Data_extraction_df["Data Migration"]
del Data_extraction_df["Data Cleaning"]
del Data_extraction_df["Data Integration"]
del Data_extraction_df["Data Collection"]
del Data_extraction_df["Data Visualization"]
del Data_extraction_df["Data Extraction"]
Data_extraction_df
# Out:
# Empty DataFrame
# Columns: [Position Title, Company Name, Company Location, Salary, Description, city, State Name, Job Title, Skills]
# Index: []

# %%
df["Data Analysis"] = (df["Description"].str.lower()
                            .str.contains("data analysis", regex=False, na=False)
                            .astype(int))
Data_Analysis_df = df.loc[df["Data Analysis"]== 1]
Data_Analysis_df["Skills"] = "Data Analysis"
del Data_Analysis_df["Data Mining"]
del Data_Analysis_df["Data Modeling"]
del Data_Analysis_df["Data Migration"]
del Data_Analysis_df["Data Cleaning"]
del Data_Analysis_df["Data Integration"]
del Data_Analysis_df["Data Collection"]
del Data_Analysis_df["Data Visualization"]
del Data_Analysis_df["Data Extraction"]
del Data_Analysis_df["Data Analysis"]
Data_Analysis_df
# Out:
# <ipython-input-16-6650d09b145f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data_Analysis_df["Skills"] = "Data Analysis"
#                                          Position Title  \
# 0                                          Data Analyst
# 4                                          Data Analyst
# 8                                          Data Analyst
# 12                                         Data Analyst
# 16                                         Data Analyst
# ...                                                 ...
# 1819  Contract Specialist/Procurement Analyst - Dire...
# 1837  Contract Specialist/Procurement Analyst - Dire...
# 1855  Contract Specialist/Procurement Analyst - Dire...
# ...

# %%
df["ETL"] = (df["Description"].str.lower()
                            .str.contains("etl", regex=False, na=False)
                            .astype(int))
ETL_df = df.loc[df["ETL"]== 1]
ETL_df["Skills"] = "ETL"
ETL_df["ETL"] = "ETL"
del ETL_df["Data Mining"]
del ETL_df["Data Modeling"]
del ETL_df["Data Migration"]
del ETL_df["Data Cleaning"]
del ETL_df["Data Integration"]
del ETL_df["Data Collection"]
del ETL_df["Data Visualization"]
del ETL_df["Data Extraction"]
del ETL_df["Data Analysis"]
del ETL_df["ETL"]
ETL_df
# Out:
# <ipython-input-17-843f7375b857>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ETL_df["Skills"] = "ETL"
# <ipython-input-17-843f7375b857>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ETL_df["ETL"] = "ETL"
#                                         Position Title  \
# 56   Interdisciplinary Computer Engineer / Computer...
# 70   Interdisciplinary Computer Engineer / Computer...
# 80   Interdisciplinary Computer Engineer / Computer...
# ...

# %%
df["Statistics"] = (df["Description"].str.lower()
                            .str.contains("statistics", regex=False, na=False)
                            .astype(int))
Statistics_df = df.loc[df["Statistics"]== 1]
Statistics_df["Skills"] = "Statistics"
del Statistics_df["Data Mining"]
del Statistics_df["Data Modeling"]
del Statistics_df["Data Migration"]
del Statistics_df["Data Cleaning"]
del Statistics_df["Data Integration"]
del Statistics_df["Data Collection"]
del Statistics_df["Data Visualization"]
del Statistics_df["Data Extraction"]
del Statistics_df["Data Analysis"]
del Statistics_df["ETL"]
del Statistics_df["Statistics"]
Statistics_df
# Out:
# <ipython-input-18-3195e344e05b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Statistics_df["Skills"] = "Statistics"
#                                          Position Title  \
# 2     Supervisory Performance Improvement / Data Ana...
# 3     Supervisory Performance Improvement / Data Ana...
# 6     Supervisory Performance Improvement / Data Ana...
# 7     Supervisory Performance Improvement / Data Ana...
# 10    Supervisory Performance Improvement / Data Ana...
# ...                                                 ...
# 1818          Procurement Analyst (Public Notice Flyer)
# 1836          Procurement Analyst (Public Notice Flyer)
# 1854          Procurement Analyst (Public Notice Flyer)
# ...

# %%
df["Web Scraping"] = (df["Description"].str.lower()
                            .str.contains("web scraping", regex=False, na=False)
                            .astype(int))
Web_scraping_df = df.loc[df["Web Scraping"]== 1]
Web_scraping_df["Skills"] = "Web Scraping"
del Web_scraping_df["Data Mining"]
del Web_scraping_df["Data Modeling"]
del Web_scraping_df["Data Migration"]
del Web_scraping_df["Data Cleaning"]
del Web_scraping_df["Data Integration"]
del Web_scraping_df["Data Collection"]
del Web_scraping_df["Data Visualization"]
del Web_scraping_df["Data Extraction"]
del Web_scraping_df["Data Analysis"]
del Web_scraping_df["ETL"]
del Web_scraping_df["Statistics"]
del Web_scraping_df["Web Scraping"]
Web_scraping_df
# Out:
# Empty DataFrame
# Columns: [Position Title, Company Name, Company Location, Salary, Description, city, State Name, Job Title, Skills]
# Index: []

# %%
df["API"] = (df["Description"].str.lower()
                            .str.contains("api", regex=False, na=False)
                            .astype(int))
Api_df = df.loc[df["API"]== 1]
Api_df["Skills"] = "API"
del Api_df["Data Mining"]
del Api_df["Data Modeling"]
del Api_df["Data Migration"]
del Api_df["Data Cleaning"]
del Api_df["Data Integration"]
del Api_df["Data Collection"]
del Api_df["Data Visualization"]
del Api_df["Data Extraction"]
del Api_df["Data Analysis"]
del Api_df["ETL"]
del Api_df["Statistics"]
del Api_df["Web Scraping"]
del Api_df["API"]
Api_df
# Out:
# <ipython-input-20-85ae91674458>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Api_df["Skills"] = "API"
#                                          Position Title  \
# 73    Computer Scientist, AST, Computer Research and...
# 93    IT Specialist (DATAMGT) (Data and Reporting An...
# 105                     IT SPECIALIST (DATA MANAGEMENT)
# 111        Lead IT Specialist (Network/Data Management)
# 114   IT Specialist (DATAMGT) (Data and Reporting An...
# ...                                                 ...
# 1858  Contract Spec/Administrator/Negotiator, Procur...
# 1873  Contract Specialist/Procurement Analyst - Dire...
# 1876  Contract Spec/Administrator/Negotiator, Procur...
# ...

# %%
all_dfs = [Data_Modeling_df, Data_Mining_df, Data_Migration_df,Data_Integration_df, Data_Collection_df, Data_visualization_df,
           Data_extraction_df, Data_Analysis_df, ETL_df, Statistics_df, Web_scraping_df, Api_df]
         
usa_gov_jobs_skills_df = pd.concat(all_dfs).reset_index(drop=True)
usa_gov_jobs_skills_df
# Out:
#                                          Position Title  \
# 0                               IT Specialist (DATAMGT)
# 1                               IT Specialist (DATAMGT)
# 2                         IT SPECIALIST (DATAMGT) (T32)
# 3                               IT Specialist (DATAMGT)
# 4                               IT Specialist (DATAMGT)
# ...                                                 ...
# 1217  Contract Spec/Administrator/Negotiator, Procur...
# 1218  Contract Specialist/Procurement Analyst - Dire...
# 1219  Contract Spec/Administrator/Negotiator, Procur...
# 1220  Contract Specialist/Procurement Analyst - Dire...
# 1221  Contract Spec/Administrator/Negotiator, Procur...
#
#                          Company Name                  Company Location  \
# 0          Department of the Treasury  Washington, District of Columbia
# 1          Department of the Treasury  Washington, District of Columbia
# 2              Department of the Army               Montgomery, Alabama
# ...

# %%
usa_gov_jobs_skills_df['Salary'] = usa_gov_jobs_skills_df['Salary'].fillna(0)

# %%
usa_gov_jobs_skills_df['Salary']=usa_gov_jobs_skills_df['Salary'].apply(lambda x:round(x,2))
usa_gov_jobs_skills_df["Salary"]= usa_gov_jobs_skills_df["Salary"].astype('int')

# %%
usa_gov_jobs_skills_df.dtypes
# Out:
# Position Title      object
# Company Name        object
# Company Location    object
# Salary               int32
# Description         object
# city                object
# State Name          object
# Job Title           object
# Skills              object
# dtype: object

# %%
usa_gov_jobs_skills_df.loc[usa_gov_jobs_skills_df['Salary'] == 0]
# Out:
# Empty DataFrame
# Columns: [Position Title, Company Name, Company Location, Salary, Description, city, State Name, Job Title, Skills]
# Index: []

# %%
usa_gov_jobs_skills_df.drop(usa_gov_jobs_skills_df.loc[usa_gov_jobs_skills_df['Salary']==0].index, inplace=True)

# %%
usa_gov_jobs_skills_df.loc[usa_gov_jobs_skills_df['Salary'] == 0]
# Out:
# Empty DataFrame
# Columns: [Position Title, Company Name, Company Location, Salary, Description, city, State Name, Job Title, Skills]
# Index: []

# %%
del usa_gov_jobs_skills_df["Description"]

# %%
usa_gov_jobs_skills_df['Salary']=usa_gov_jobs_skills_df['Salary'].apply(lambda x:round(x,2))
usa_gov_jobs_skills_df["Salary"]= usa_gov_jobs_skills_df["Salary"].astype('int')
# usa_gov_jobs_skills_df["Salary"]= usa_gov_jobs_skills_df["Salary"].apply(str)

# %%
# usa_gov_jobs_skills_df.to_csv("cpj_usagovjobs_skills_categorized.csv")
