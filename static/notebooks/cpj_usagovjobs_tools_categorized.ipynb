# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../Resources/cpj_usajobcategorized_with_description.csv")

# %%
df
# Out:
#                                          Position Title  \
# 0                                          Data Analyst
# 1               Health System Specialist (Data Analyst)
# 2     Supervisory Performance Improvement / Data Ana...
# 3     Supervisory Performance Improvement / Data Ana...
# 4                                          Data Analyst
# ...                                                 ...
# 1890          Procurement Analyst (Public Notice Flyer)
# 1891  Contract Specialist/Procurement Analyst - Dire...
# 1892  Contract Specialist/Procurement Analyst (Direc...
# 1893  Contract Specialist/Procurement Analyst (Direc...
# 1894  Contract Spec/Administrator/Negotiator, Procur...
#
#                                       Company Name  \
# 0     Other Agencies and Independent Organizations
# 1                   Department of Veterans Affairs
# 2          Department of Health And Human Services
# 3          Department of Health And Human Services
# ...

# %%
df["Python"] = (df["Description"].str.lower()
                            .str.contains("python", regex=False, na=False)
                            .astype(int))
Python_df = df.loc[df["Python"]== 1]
Python_df["Tools"] = "Python"
del Python_df["Python"]
Python_df
# Out:
# <ipython-input-4-47375069c28d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Python_df["Tools"] = "Python"
#                                          Position Title  \
# 95                              IT Specialist (DATAMGT)
# 96                              IT Specialist (DATAMGT)
# 116                             IT Specialist (DATAMGT)
# 117                             IT Specialist (DATAMGT)
# 136                             IT Specialist (DATAMGT)
# ...                                                 ...
# 997   Operations Research Analyst (Senior Financial ...
# 1032  Operations Research Analyst (Senior Financial ...
# 1033  Operations Research Analyst (Senior Financial ...
# ...

# %%
df["SQL"] = (df["Description"].str.lower()
                            .str.contains("sql", regex=False, na=False)
                            .astype(int))
Sql_df = df.loc[df["SQL"]== 1]
Sql_df["Tools"] = "SQL"
del Sql_df["Python"]
del Sql_df["SQL"]
Sql_df
# Out:
# <ipython-input-5-e1dd65ba6dab>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sql_df["Tools"] = "SQL"
#                             Position Title  \
# 0                             Data Analyst
# 4                             Data Analyst
# 8                             Data Analyst
# 12                            Data Analyst
# 16                            Data Analyst
# 20                            Data Analyst
# 24                            Data Analyst
# 28                            Data Analyst
# 32                            Data Analyst
# 36                            Data Analyst
# 40                            Data Analyst
# 44                            Data Analyst
# 48                            Data Analyst
# ...

# %%
df["Spark"] = (df["Description"].str.lower()
                            .str.contains("Spark", regex=False, na=False)
                            .astype(int))
Spark_df = df.loc[df["Spark"]== 1]
Spark_df["Tools"] = "Spark"
del Spark_df["Python"]
del Spark_df["SQL"]
del Spark_df["Spark"]
Spark_df
# Out:
# Empty DataFrame
# Columns: [Position Title, Company Name, Company Location, Salary, Description, city, State Name, Job Title, Tools]
# Index: []

# %%
df["JavaScript"] = (df["Description"].str.lower()
                            .str.contains("JavaScript", regex=False, na=False)
                            .astype(int))
JavaScript_df = df.loc[df["JavaScript"]== 1]
JavaScript_df["Tools"] = "JavaScript"
del JavaScript_df["Python"]
del JavaScript_df["SQL"]
del JavaScript_df["Spark"]
del JavaScript_df["JavaScript"]
JavaScript_df
# Out:
# Empty DataFrame
# Columns: [Position Title, Company Name, Company Location, Salary, Description, city, State Name, Job Title, Tools]
# Index: []

# %%
df["R"] = (df["Description"].str.upper()
                            .str.contains(" R ", regex=False, na=False)
                            .astype(int))
R_df = df.loc[df["R"]== 1]
R_df["Tools"] = "R"
del R_df["Python"]
del R_df["SQL"]
del R_df["Spark"]
del R_df["JavaScript"]
del R_df["R"]
R_df
# Out:
# <ipython-input-8-30d615fef138>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   R_df["Tools"] = "R"
#                                          Position Title  \
# 377                         IT SPECIALIST (SYSANALYSIS)
# 535   Operations Research Analyst (Senior Financial ...
# 536   Operations Research Analyst (Senior Financial ...
# 568   Operations Research Analyst (Senior Financial ...
# 569   Operations Research Analyst (Senior Financial ...
# 572   Operations Research Analyst (Senior Financial ...
# 573   Operations Research Analyst (Senior Financial ...
# 574   Operations Research Analyst (Senior Financial ...
# 575   Operations Research Analyst (Senior Financial ...
# 576   Operations Research Analyst (Senior Financial ...
# ...

# %%
df["NoSQL"] = (df["Description"].str.lower()
                            .str.contains("nosql", regex=False, na=False)
                            .astype(int))
NoSql_df = df.loc[df["NoSQL"]== 1]
NoSql_df["Tools"] = "NoSQL"
del NoSql_df["Python"]
del NoSql_df["SQL"]
del NoSql_df["Spark"]
del NoSql_df["JavaScript"]
del NoSql_df["NoSQL"]
del NoSql_df["R"]
NoSql_df
# Out:
# Empty DataFrame
# Columns: [Position Title, Company Name, Company Location, Salary, Description, city, State Name, Job Title, Tools]
# Index: []

# %%
df["AWS"] = (df["Description"].str.lower()
                            .str.contains("AWS", regex=False, na=False)
                            .astype(int))
Aws_df = df.loc[df["AWS"]== 1]
Aws_df["Tools"] = "AWS"
del Aws_df["Python"]
del Aws_df["SQL"]
del Aws_df["Spark"]
del Aws_df["JavaScript"]
del Aws_df["NoSQL"]
del Aws_df["AWS"]
del Aws_df["R"]
Aws_df
# Out:
# Empty DataFrame
# Columns: [Position Title, Company Name, Company Location, Salary, Description, city, State Name, Job Title, Tools]
# Index: []

# %%
df["Azure"] = (df["Description"].str.lower()
                            .str.contains("azure", regex=False, na=False)
                            .astype(int))
Azure_df = df.loc[df["Azure"]== 1]
Azure_df["Tools"] = "Azure"
del Azure_df["Python"]
del Azure_df["SQL"]
del Azure_df["Spark"]
del Azure_df["JavaScript"]
del Azure_df["NoSQL"]
del Azure_df["AWS"]
del Azure_df["Azure"]
del Azure_df["R"]
Azure_df
# Out:
# <ipython-input-11-4a4842079acc>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Azure_df["Tools"] = "Azure"
#                                         Position Title  \
# 112  Senior IT Specialist, (DATAMGT) CG-2210-15 TEM...
# 133  Senior IT Specialist, (DATAMGT) CG-2210-15 TEM...
# 153  Senior IT Specialist, (DATAMGT) CG-2210-15 TEM...
# 174  Senior IT Specialist, (DATAMGT) CG-2210-15 TEM...
# 199  Senior IT Specialist, (DATAMGT) CG-2210-15 TEM...
# 239  Senior IT Specialist, (DATAMGT) CG-2210-15 TEM...
# 259  Senior IT Specialist, (DATAMGT) CG-2210-15 TEM...
# 316                              IT SPECIALIST (APPSW)
# 318                              IT SPECIALIST (APPSW)
# 319                              IT Specialist (Appsw)
# ...

# %%
df["Google Cloud"] = (df["Description"].str.lower()
                            .str.contains("google cloud", regex=False, na=False)
                            .astype(int))
Google_Cloud_df = df.loc[df["Google Cloud"]== 1]
Google_Cloud_df["Tools"] = "Google Cloud"
del Google_Cloud_df["Python"]
del Google_Cloud_df["SQL"]
del Google_Cloud_df["Spark"]
del Google_Cloud_df["JavaScript"]
del Google_Cloud_df["NoSQL"]
del Google_Cloud_df["AWS"]
del Google_Cloud_df["Azure"]
del Google_Cloud_df["Google Cloud"]
del Google_Cloud_df["R"]
Google_Cloud_df
# Out:
# Empty DataFrame
# Columns: [Position Title, Company Name, Company Location, Salary, Description, city, State Name, Job Title, Tools]
# Index: []

# %%
df["Cloud"] = (df["Description"].str.lower()
                            .str.contains("Cloud", regex=False, na=False)
                            .astype(int))
Cloud_df = df.loc[df["Cloud"]== 1]
Cloud_df["Tools"] = "Cloud"
del Cloud_df["Python"]
del Cloud_df["SQL"]
del Cloud_df["Spark"]
del Cloud_df["JavaScript"]
del Cloud_df["NoSQL"]
del Cloud_df["AWS"]
del Cloud_df["Azure"]
del Cloud_df["Google Cloud"]
del Cloud_df["Cloud"]
del Cloud_df["R"]
Cloud_df
# Out:
# Empty DataFrame
# Columns: [Position Title, Company Name, Company Location, Salary, Description, city, State Name, Job Title, Tools]
# Index: []

# %%
df["HTML"] = (df["Description"].str.lower()
                            .str.contains("html", regex=False, na=False)
                            .astype(int))
Html_df = df.loc[df["HTML"]== 1]
Html_df["Tools"] = "HTML"
del Html_df["Python"]
del Html_df["SQL"]
del Html_df["Spark"]
del Html_df["JavaScript"]
del Html_df["NoSQL"]
del Html_df["AWS"]
del Html_df["Azure"]
del Html_df["Google Cloud"]
del Html_df["Cloud"]
del Html_df["HTML"]
del Html_df["R"]
Html_df
# Out:
# <ipython-input-14-2510091f0abe>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Html_df["Tools"] = "HTML"
#                                          Position Title  \
# 2     Supervisory Performance Improvement / Data Ana...
# 3     Supervisory Performance Improvement / Data Ana...
# 6     Supervisory Performance Improvement / Data Ana...
# 7     Supervisory Performance Improvement / Data Ana...
# 10    Supervisory Performance Improvement / Data Ana...
# ...                                                 ...
# 1877                                Procurement Analyst
# 1879                                Procurement Analyst
# 1882                                PROCUREMENT ANALYST
# ...

# %%
df["CSS"] = (df["Description"].str.lower()
                            .str.contains("css", regex=False, na=False)
                            .astype(int))
css_df = df.loc[df["CSS"]== 1]
css_df["Tools"] = "CSS"
del css_df["Python"]
del css_df["SQL"]
del css_df["Spark"]
del css_df["JavaScript"]
del css_df["NoSQL"]
del css_df["AWS"]
del css_df["Azure"]
del css_df["Google Cloud"]
del css_df["Cloud"]
del css_df["HTML"]
del css_df["CSS"]
del css_df["R"]
css_df
# Out:
# <ipython-input-15-2547a7a6ca3a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   css_df["Tools"] = "CSS"
#                             Position Title                  Company Name  \
# 107        IT Specialist (Data Management)        Department of the Army
# 128        IT Specialist (Data Management)        Department of the Army
# 148        IT Specialist (Data Management)        Department of the Army
# 168        IT Specialist (Data Management)        Department of the Army
# 193        IT Specialist (Data Management)        Department of the Army
# 234        IT Specialist (Data Management)        Department of the Army
# 254        IT Specialist (Data Management)        Department of the Army
# ...

# %%
df["DataBricks"] = (df["Description"].str.lower()
                            .str.contains("databricks", regex=False, na=False)
                            .astype(int))
Databricks_df = df.loc[df["DataBricks"]== 1]
Databricks_df["Tools"] = "DataBricks"
del Databricks_df["Python"]
del Databricks_df["SQL"]
del Databricks_df["Spark"]
del Databricks_df["JavaScript"]
del Databricks_df["NoSQL"]
del Databricks_df["AWS"]
del Databricks_df["Azure"]
del Databricks_df["Google Cloud"]
del Databricks_df["Cloud"]
del Databricks_df["HTML"]
del Databricks_df["CSS"]
del Databricks_df["R"]
del Databricks_df["DataBricks"]
Databricks_df
# Out:
# Empty DataFrame
# Columns: [Position Title, Company Name, Company Location, Salary, Description, city, State Name, Job Title, Tools]
# Index: []

# %%
df["Snowflake"] = (df["Description"].str.lower()
                            .str.contains("snowflake", regex=False, na=False)
                            .astype(int))
Snowflake_df = df.loc[df["Snowflake"]== 1]
Snowflake_df["Tools"] = "Snowflake"
del Snowflake_df["Python"]
del Snowflake_df["SQL"]
del Snowflake_df["Spark"]
del Snowflake_df["JavaScript"]
del Snowflake_df["NoSQL"]
del Snowflake_df["AWS"]
del Snowflake_df["Azure"]
del Snowflake_df["Google Cloud"]
del Snowflake_df["Cloud"]
del Snowflake_df["HTML"]
del Snowflake_df["CSS"]
del Snowflake_df["Snowflake"]
del Snowflake_df["R"]
del Snowflake_df["DataBricks"]
Snowflake_df
# Out:
# Empty DataFrame
# Columns: [Position Title, Company Name, Company Location, Salary, Description, city, State Name, Job Title, Tools]
# Index: []

# %%
df["PyTorch"] = (df["Description"].str.lower()
                            .str.contains("pytorch", regex=False, na=False)
                            .astype(int))
PyTorch_df = df.loc[df["PyTorch"]== 1]
PyTorch_df["Tools"] = "PyTorch"
del PyTorch_df["Python"]
del PyTorch_df["SQL"]
del PyTorch_df["Spark"]
del PyTorch_df["JavaScript"]
del PyTorch_df["NoSQL"]
del PyTorch_df["AWS"]
del PyTorch_df["Azure"]
del PyTorch_df["Google Cloud"]
del PyTorch_df["Cloud"]
del PyTorch_df["HTML"]
del PyTorch_df["CSS"]
del PyTorch_df["Snowflake"]
del PyTorch_df["R"]
del PyTorch_df["PyTorch"]

PyTorch_df
# Out:
# Empty DataFrame
# Columns: [Position Title, Company Name, Company Location, Salary, Description, city, State Name, Job Title, DataBricks, Tools]
# Index: []

# %%
df["GCP"] = (df["Description"].str.lower()
                            .str.contains("gcp", regex=False, na=False)
                            .astype(int))
Gcp_df = df.loc[df["GCP"]== 1]
Gcp_df["Tools"] = "GCP"
del Gcp_df["Python"]
del Gcp_df["SQL"]
del Gcp_df["Spark"]
del Gcp_df["JavaScript"]
del Gcp_df["NoSQL"]
del Gcp_df["AWS"]
del Gcp_df["Azure"]
del Gcp_df["Google Cloud"]
del Gcp_df["Cloud"]
del Gcp_df["HTML"]
del Gcp_df["CSS"]
del Gcp_df["Snowflake"]
del Gcp_df["DataBricks"]
del Gcp_df["PyTorch"]
del Gcp_df["GCP"]
del Gcp_df["R"]

Gcp_df
# Out:
# Empty DataFrame
# Columns: [Position Title, Company Name, Company Location, Salary, Description, city, State Name, Job Title, Tools]
# Index: []

# %%
df["Excel"] = (df["Description"].str.lower()
                            .str.contains("excel", regex=False, na=False)
                            .astype(int))
Excel_df = df.loc[df["Excel"]== 1]
Excel_df["Tools"] = "Excel"
del Excel_df["Python"]
del Excel_df["SQL"]
del Excel_df["Spark"]
del Excel_df["JavaScript"]
del Excel_df["NoSQL"]
del Excel_df["AWS"]
del Excel_df["Azure"]
del Excel_df["Google Cloud"]
del Excel_df["Cloud"]
del Excel_df["HTML"]
del Excel_df["CSS"]
del Excel_df["Snowflake"]
del Excel_df["DataBricks"]
del Excel_df["PyTorch"]
del Excel_df["GCP"]
del Excel_df["Excel"]
del Excel_df["R"]
Excel_df
# Out:
# <ipython-input-20-799e6dbde0dc>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Excel_df["Tools"] = "Excel"
#                                          Position Title  \
# 53    Computer Engineer, Computer Scientist, Electri...
# 75    Computer Engineer, Computer Scientist, Electri...
# 77    Computer Engineer, Computer Scientist, Electri...
# 82    Computer Engineer, Computer Scientist, Electri...
# 95                              IT Specialist (DATAMGT)
# ...                                                 ...
# 1818          Procurement Analyst (Public Notice Flyer)
# 1836          Procurement Analyst (Public Notice Flyer)
# 1854          Procurement Analyst (Public Notice Flyer)
# ...

# %%
df["VBA"] = (df["Description"].str.lower()
                            .str.contains("vba", regex=False, na=False)
                            .astype(int))
Vba_df = df.loc[df["VBA"]== 1]
Vba_df["Tools"] = "VBA"
del Vba_df["Python"]
del Vba_df["SQL"]
del Vba_df["Spark"]
del Vba_df["JavaScript"]
del Vba_df["NoSQL"]
del Vba_df["AWS"]
del Vba_df["Azure"]
del Vba_df["Google Cloud"]
del Vba_df["Cloud"]
del Vba_df["HTML"]
del Vba_df["CSS"]
del Vba_df["Snowflake"]
del Vba_df["DataBricks"]
del Vba_df["PyTorch"]
del Vba_df["GCP"]
del Vba_df["Excel"]
del Vba_df["VBA"]
del Vba_df["R"]
Vba_df
# Out:
# <ipython-input-21-d926b59e66c5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Vba_df["Tools"] = "VBA"
#                       Position Title                    Company Name  \
# 1114  Management and Program Analyst  Department of Veterans Affairs
# 1207  Management and Program Analyst  Department of Veterans Affairs
# 1295  Management and Program Analyst  Department of Veterans Affairs
# 1385  Management and Program Analyst  Department of Veterans Affairs
# 1473  Management and Program Analyst  Department of Veterans Affairs
# 1568  Management and Program Analyst  Department of Veterans Affairs
# 1657  Management and Program Analyst  Department of Veterans Affairs
#
#                       Company Location  Salary  \
# ...

# %%
df["PowerBI"] = (df["Description"].str.lower()
                            .str.contains("powerbi", regex=False, na=False)
                            .astype(int))
PowerBI_df = df.loc[df["PowerBI"]== 1]
PowerBI_df["Tools"] = "PowerBI"
del PowerBI_df["Python"]
del PowerBI_df["SQL"]
del PowerBI_df["Spark"]
del PowerBI_df["JavaScript"]
del PowerBI_df["NoSQL"]
del PowerBI_df["AWS"]
del PowerBI_df["Azure"]
del PowerBI_df["Google Cloud"]
del PowerBI_df["Cloud"]
del PowerBI_df["HTML"]
del PowerBI_df["CSS"]
del PowerBI_df["Snowflake"]
del PowerBI_df["DataBricks"]
del PowerBI_df["PyTorch"]
del PowerBI_df["GCP"]
del PowerBI_df["Excel"]
del PowerBI_df["VBA"]
del PowerBI_df["PowerBI"]
del PowerBI_df["R"]
PowerBI_df
# Out:
# <ipython-input-22-54c36644a965>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PowerBI_df["Tools"] = "PowerBI"
#             Position Title                Company Name      Company Location  \
# 316  IT SPECIALIST (APPSW)  Department of the Interior  No location provided
#
#      Salary                                        Description  \
# 316   92143  Help\r\n                                    \n...
#
#                      city State Name      Job Title    Tools
# 316  No location provided        NaN  IT Specialist  PowerBI

# %%
df["Tableau"] = (df["Description"].str.lower()
                            .str.contains("tableau", regex=False, na=False)
                            .astype(int))
Tableau_df = df.loc[df["Tableau"]== 1]
Tableau_df["Tools"] = "Tableau"
del Tableau_df["Python"]
del Tableau_df["SQL"]
del Tableau_df["Spark"]
del Tableau_df["JavaScript"]
del Tableau_df["NoSQL"]
del Tableau_df["AWS"]
del Tableau_df["Azure"]
del Tableau_df["Google Cloud"]
del Tableau_df["Cloud"]
del Tableau_df["HTML"]
del Tableau_df["CSS"]
del Tableau_df["Snowflake"]
del Tableau_df["DataBricks"]
del Tableau_df["PyTorch"]
del Tableau_df["GCP"]
del Tableau_df["Excel"]
del Tableau_df["VBA"]
del Tableau_df["PowerBI"]
del Tableau_df["Tableau"]
del Tableau_df["R"]
Tableau_df
# Out:
# <ipython-input-23-1dfa79ea0cf1>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tableau_df["Tools"] = "Tableau"
#             Position Title                                  Company Name  \
# 0             Data Analyst  Other Agencies and Independent Organizations
# 4             Data Analyst  Other Agencies and Independent Organizations
# 8             Data Analyst  Other Agencies and Independent Organizations
# 12            Data Analyst  Other Agencies and Independent Organizations
# 16            Data Analyst  Other Agencies and Independent Organizations
# 20            Data Analyst  Other Agencies and Independent Organizations
# 24            Data Analyst  Other Agencies and Independent Organizations
# ...

# %%
df["Hadoop"] = (df["Description"].str.lower()
                            .str.contains("hadoop", regex=False, na=False)
                            .astype(int))
Hadoop_df = df.loc[df["Hadoop"]== 1]
Hadoop_df["Tools"] = "Hadoop"
del Hadoop_df["Python"]
del Hadoop_df["SQL"]
del Hadoop_df["Spark"]
del Hadoop_df["JavaScript"]
del Hadoop_df["NoSQL"]
del Hadoop_df["AWS"]
del Hadoop_df["Azure"]
del Hadoop_df["Google Cloud"]
del Hadoop_df["Cloud"]
del Hadoop_df["HTML"]
del Hadoop_df["CSS"]
del Hadoop_df["Snowflake"]
del Hadoop_df["DataBricks"]
del Hadoop_df["PyTorch"]
del Hadoop_df["GCP"]
del Hadoop_df["Excel"]
del Hadoop_df["VBA"]
del Hadoop_df["PowerBI"]
del Hadoop_df["Tableau"]
del Hadoop_df["Hadoop"]
del Hadoop_df["R"]
Hadoop_df
# Out:
# <ipython-input-24-04f3efe7d83f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Hadoop_df["Tools"] = "Hadoop"
#                       Position Title           Company Name  \
# 105  IT SPECIALIST (DATA MANAGEMENT)  Department of Defense
# 126  IT SPECIALIST (DATA MANAGEMENT)  Department of Defense
# 146  IT SPECIALIST (DATA MANAGEMENT)  Department of Defense
# 166  IT SPECIALIST (DATA MANAGEMENT)  Department of Defense
# 191  IT SPECIALIST (DATA MANAGEMENT)  Department of Defense
# 232  IT SPECIALIST (DATA MANAGEMENT)  Department of Defense
# 252  IT SPECIALIST (DATA MANAGEMENT)  Department of Defense
# 431  IT SPECIALIST (DATA MANAGEMENT)  Department of Defense
#
#        Company Location  Salary  \
# 105  Bethesda, Maryland   10369
# ...

# %%
df["Scala"] = (df["Description"].str.lower()
                            .str.contains("scala", regex=False, na=False)
                            .astype(int))
Scala_df = df.loc[df["Scala"]== 1]
Scala_df["Tools"] = "Scala"
del Scala_df["Python"]
del Scala_df["SQL"]
del Scala_df["Spark"]
del Scala_df["JavaScript"]
del Scala_df["NoSQL"]
del Scala_df["AWS"]
del Scala_df["Azure"]
del Scala_df["Google Cloud"]
del Scala_df["Cloud"]
del Scala_df["HTML"]
del Scala_df["CSS"]
del Scala_df["Snowflake"]
del Scala_df["DataBricks"]
del Scala_df["PyTorch"]
del Scala_df["GCP"]
del Scala_df["Excel"]
del Scala_df["VBA"]
del Scala_df["PowerBI"]
del Scala_df["Tableau"]
del Scala_df["Hadoop"]
del Scala_df["Scala"]
del Scala_df["R"]
Scala_df
# Out:
# <ipython-input-25-3882d189063d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Scala_df["Tools"] = "Scala"
#                                          Position Title  \
# 56    Interdisciplinary Computer Engineer / Computer...
# 70    Interdisciplinary Computer Engineer / Computer...
# 80    Interdisciplinary Computer Engineer / Computer...
# 85    Interdisciplinary Computer Engineer / Computer...
# 100                       IT SPECIALIST (DATAMGT) (T32)
# 113                IT Specialist (Helpdesk Analyst) NF3
# 121                       IT SPECIALIST (DATAMGT) (T32)
# 141                       IT SPECIALIST (DATAMGT) (T32)
# 161                       IT SPECIALIST (DATAMGT) (T32)
# ...

# %%
df["Java"] = (df["Description"].str.lower()
                            .str.contains("java", regex=False, na=False)
                            .astype(int))
Java_df = df.loc[df["Java"]== 1]
Java_df["Tools"] = "Java"
del Java_df["Python"]
del Java_df["SQL"]
del Java_df["Spark"]
del Java_df["JavaScript"]
del Java_df["NoSQL"]
del Java_df["AWS"]
del Java_df["Azure"]
del Java_df["Google Cloud"]
del Java_df["Cloud"]
del Java_df["HTML"]
del Java_df["CSS"]
del Java_df["Snowflake"]
del Java_df["DataBricks"]
del Java_df["PyTorch"]
del Java_df["GCP"]
del Java_df["Excel"]
del Java_df["VBA"]
del Java_df["PowerBI"]
del Java_df["Tableau"]
del Java_df["Hadoop"]
del Java_df["Scala"]
del Java_df["Java"]
del Java_df["R"]
Java_df
# Out:
# <ipython-input-26-7ac669c611e0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Java_df["Tools"] = "Java"
#                             Position Title                     Company Name  \
# 95                 IT Specialist (DATAMGT)       Department of the Treasury
# 96                 IT Specialist (DATAMGT)       Department of the Treasury
# 107        IT Specialist (Data Management)           Department of the Army
# 116                IT Specialist (DATAMGT)       Department of the Treasury
# 117                IT Specialist (DATAMGT)       Department of the Treasury
# 128        IT Specialist (Data Management)           Department of the Army
# 136                IT Specialist (DATAMGT)       Department of the Treasury
# ...

# %%
df["AI"] = (df["Description"].str.upper()
                            .str.contains(" AI ", regex=False, na=False)
                            .astype(int))
AI_df = df.loc[df["AI"]== 1]
AI_df["Tools"] = "AI"
del AI_df["Python"]
del AI_df["SQL"]
del AI_df["Spark"]
del AI_df["JavaScript"]
del AI_df["NoSQL"]
del AI_df["AWS"]
del AI_df["Azure"]
del AI_df["Google Cloud"]
del AI_df["Cloud"]
del AI_df["HTML"]
del AI_df["CSS"]
del AI_df["Snowflake"]
del AI_df["DataBricks"]
del AI_df["PyTorch"]
del AI_df["GCP"]
del AI_df["Excel"]
del AI_df["VBA"]
del AI_df["PowerBI"]
del AI_df["Tableau"]
del AI_df["Hadoop"]
del AI_df["Scala"]
del AI_df["Java"]
del AI_df["R"]
del AI_df["AI"]

AI_df
# Out:
# <ipython-input-27-f8d6170cf9a0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AI_df["Tools"] = "AI"
#               Position Title            Company Name Company Location  Salary  \
# 325  IT SPECIALIST (PLCYPLN)  Department of the Navy   Crane, Indiana   77488
#
#                                            Description   city State Name  \
# 325  Help\r\n                                    \n...  Crane    Indiana
#
#          Job Title Tools
# 325  IT Specialist    AI

# %%
df["Machine Learning"] = (df["Description"].str.lower()
                            .str.contains("machine learning", regex=False, na=False)
                            .astype(int))
Machine_Learning_df= df.loc[df["Machine Learning"]== 1]
Machine_Learning_df["Tools"] = "Machine Learning"
del Machine_Learning_df["Python"]
del Machine_Learning_df["SQL"]
del Machine_Learning_df["Spark"]
del Machine_Learning_df["JavaScript"]
del Machine_Learning_df["NoSQL"]
del Machine_Learning_df["AWS"]
del Machine_Learning_df["Azure"]
del Machine_Learning_df["Google Cloud"]
del Machine_Learning_df["Cloud"]
del Machine_Learning_df["HTML"]
del Machine_Learning_df["CSS"]
del Machine_Learning_df["Snowflake"]
del Machine_Learning_df["DataBricks"]
del Machine_Learning_df["PyTorch"]
del Machine_Learning_df["GCP"]
del Machine_Learning_df["Excel"]
del Machine_Learning_df["VBA"]
del Machine_Learning_df["PowerBI"]
del Machine_Learning_df["Tableau"]
del Machine_Learning_df["Hadoop"]
del Machine_Learning_df["Scala"]
del Machine_Learning_df["Java"]
del Machine_Learning_df["Machine Learning"]
del Machine_Learning_df["R"]
del Machine_Learning_df["AI"]
Machine_Learning_df
# Out:
# <ipython-input-28-1baeeabf93c0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Machine_Learning_df["Tools"] = "Machine Learning"
#                                          Position Title  \
# 325                             IT SPECIALIST (PLCYPLN)
# 503                 SUPERVISORY IT SPECIALIST (INFOSEC)
# 552                         Operations Research Analyst
# 556                         Operations Research Analyst
# 597                         Operations Research Analyst
# 601                         Operations Research Analyst
# 630                         Operations Research Analyst
# 634                         Operations Research Analyst
# 663                         Operations Research Analyst
# ...

# %%
df["Deep Learning"] = (df["Description"].str.lower()
                            .str.contains("deep learning", regex=False, na=False)
                            .astype(int))
Deep_Learning_df= df.loc[df["Deep Learning"]== 1]
Deep_Learning_df["Tools"] = "Deep Learning"
del Deep_Learning_df["Python"]
del Deep_Learning_df["SQL"]
del Deep_Learning_df["Spark"]
del Deep_Learning_df["JavaScript"]
del Deep_Learning_df["NoSQL"]
del Deep_Learning_df["AWS"]
del Deep_Learning_df["Azure"]
del Deep_Learning_df["Google Cloud"]
del Deep_Learning_df["Cloud"]
del Deep_Learning_df["HTML"]
del Deep_Learning_df["CSS"]
del Deep_Learning_df["Snowflake"]
del Deep_Learning_df["DataBricks"]
del Deep_Learning_df["PyTorch"]
del Deep_Learning_df["GCP"]
del Deep_Learning_df["Excel"]
del Deep_Learning_df["VBA"]
del Deep_Learning_df["PowerBI"]
del Deep_Learning_df["Tableau"]
del Deep_Learning_df["Hadoop"]
del Deep_Learning_df["Scala"]
del Deep_Learning_df["Java"]
del Deep_Learning_df["Machine Learning"]
del Deep_Learning_df["Deep Learning"]
del Deep_Learning_df["R"]
del Deep_Learning_df["AI"]
Deep_Learning_df
# Out:
# <ipython-input-29-f60f3a4f9ead>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Deep_Learning_df["Tools"] = "Deep Learning"
#         Position Title                Company Name      Company Location  \
# 62  Computer Scientist  Department of the Treasury  No location provided
#
#     Salary                                        Description  \
# 62   11097  Help\r\n                                    \n...
#
#                     city State Name           Job Title          Tools
# 62  No location provided        NaN  Computer Scientist  Deep Learning

# %%
df["Alteryx"] = (df["Description"].str.lower()
                            .str.contains("Alteryx", regex=False, na=False)
                            .astype(int))
Alteryx_df= df.loc[df["Alteryx"]== 1]
Alteryx_df["Tools"] = "Alteryx"
del Alteryx_df["Python"]
del Alteryx_df["SQL"]
del Alteryx_df["Spark"]
del Alteryx_df["JavaScript"]
del Alteryx_df["NoSQL"]
del Alteryx_df["AWS"]
del Alteryx_df["Azure"]
del Alteryx_df["Google Cloud"]
del Alteryx_df["Cloud"]
del Alteryx_df["HTML"]
del Alteryx_df["CSS"]
del Alteryx_df["Snowflake"]
del Alteryx_df["DataBricks"]
del Alteryx_df["PyTorch"]
del Alteryx_df["GCP"]
del Alteryx_df["Excel"]
del Alteryx_df["VBA"]
del Alteryx_df["PowerBI"]
del Alteryx_df["Tableau"]
del Alteryx_df["Hadoop"]
del Alteryx_df["Scala"]
del Alteryx_df["Java"]
del Alteryx_df["Machine Learning"]
del Alteryx_df["Deep Learning"]
del Alteryx_df["R"]
del Alteryx_df["AI"]
Alteryx_df
# Out:
# Empty DataFrame
# Columns: [Position Title, Company Name, Company Location, Salary, Description, city, State Name, Job Title, Alteryx, Tools]
# Index: []

# %%
all_dfs = [Python_df, Sql_df, R_df, NoSql_df, Azure_df,Html_df, css_df, Gcp_df,Excel_df, Vba_df, 
           PowerBI_df, Tableau_df, Hadoop_df, Scala_df, Java_df, AI_df, Machine_Learning_df, 
           Deep_Learning_df]
         
usa_gov_jobs_tools_df = pd.concat(all_dfs).reset_index(drop=True)
usa_gov_jobs_tools_df
# Out:
#                                         Position Title  \
# 0                              IT Specialist (DATAMGT)
# 1                              IT Specialist (DATAMGT)
# 2                              IT Specialist (DATAMGT)
# 3                              IT Specialist (DATAMGT)
# 4                              IT Specialist (DATAMGT)
# ..                                                 ...
# 825  Supervisory Management and Program Analyst (Da...
# 826  Supervisory Management and Program Analyst (Da...
# 827  Supervisory Management and Program Analyst (Da...
# 828  Supervisory Management and Program Analyst (Da...
# 829                                 Computer Scientist
#
#                    Company Name                  Company Location  Salary  \
# 0    Department of the Treasury  Washington, District of Columbia   11961
# 1    Department of the Treasury  Washington, District of Columbia   11961
# 2    Department of the Treasury  Washington, District of Columbia   11961
# ...

# %%
usa_gov_jobs_tools_df["Tools"].unique().tolist()
# Out:
# ['Python',
#  'SQL',
#  'R',
#  'Azure',
#  'HTML',
#  'CSS',
#  'Excel',
#  'VBA',
#  'PowerBI',
#  'Tableau',
#  'Hadoop',
#  'Scala',
#  'Java',
#  'AI',
#  'Machine Learning',
#  'Deep Learning']

# %%
usa_gov_jobs_tools_df['Salary'] = usa_gov_jobs_tools_df['Salary'].fillna(0)

# %%
usa_gov_jobs_tools_df['Salary']=usa_gov_jobs_tools_df['Salary'].apply(lambda x:round(x,2))
usa_gov_jobs_tools_df["Salary"]= usa_gov_jobs_tools_df["Salary"].astype('int')

# %%
usa_gov_jobs_tools_df.dtypes
# Out:
# Position Title      object
# Company Name        object
# Company Location    object
# Salary               int32
# Description         object
# city                object
# State Name          object
# Job Title           object
# Tools               object
# dtype: object

# %%
usa_gov_jobs_tools_df.loc[usa_gov_jobs_tools_df['Salary'] == 0]
# Out:
# Empty DataFrame
# Columns: [Position Title, Company Name, Company Location, Salary, Description, city, State Name, Job Title, Tools]
# Index: []

# %%
usa_gov_jobs_tools_df.drop(usa_gov_jobs_tools_df.loc[usa_gov_jobs_tools_df['Salary']==0].index, inplace=True)

# %%
usa_gov_jobs_tools_df.loc[usa_gov_jobs_tools_df['Salary'] == 0]
# Out:
# Empty DataFrame
# Columns: [Position Title, Company Name, Company Location, Salary, Description, city, State Name, Job Title, Tools]
# Index: []

# %%
del usa_gov_jobs_tools_df["Description"]

# %%
usa_gov_jobs_tools_df["Salary"]= usa_gov_jobs_tools_df["Salary"].apply(str)
usa_gov_jobs_tools_df["Salary"]= '$' + usa_gov_jobs_tools_df["Salary"].astype(str)

# %%
# usa_gov_jobs_tools_df.to_csv("../Resources/cpj_usagovjobs_tools_categorized.csv")
