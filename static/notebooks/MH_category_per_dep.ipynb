# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as py
import time
from datetime import datetime

# %%
gov_file = "category_perDepartment.csv"

gov_df = pd.read_csv(gov_file)

gov_df.head()
# Out:
#                                    Company Name  Job Category
# 0  Other Agencies and Independent Organizations  Data Analyst
# 1                    Department of the Treasury  Data Analyst
# 2                Department of Veterans Affairs  Data Analyst
# 3                Department of Veterans Affairs  Data Analyst
# 4  Other Agencies and Independent Organizations  Data Analyst

# %%
#gov_df.to_csv('category_vs_dep.csv')

# %%
gov_df2 = gov_df.groupby(['Company Name','Job Category']).max().reset_index()

# %%
gov_df2
# Out:
#                                           Company Name  \
# 0    Court Services and Offender Supervision Agency...
# 1    Court Services and Offender Supervision Agency...
# 2    Court Services and Offender Supervision Agency...
# 3    Court Services and Offender Supervision Agency...
# 4    Court Services and Offender Supervision Agency...
# ..                                                 ...
# 344       Other Agencies and Independent Organizations
# 345       Other Agencies and Independent Organizations
# 346       Other Agencies and Independent Organizations
# 347       Other Agencies and Independent Organizations
# 348       Other Agencies and Independent Organizations
#
#                       Job Category
# 0    Business Intelligence Analyst
# 1         Business Systems Analyst
# 2                     Data Analyst
# 3               IT Systems Analyst
# 4                Logistics Analyst
# ..                             ...
# 344              Logistics Analyst
# ...
